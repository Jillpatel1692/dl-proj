# %%
# Import necessary libraries
import numpy as np  # NumPy for numerical operations
import pandas as pd  # Pandas for data manipulation and analysis
from sklearn.feature_extraction.text import TfidfVectorizer  # TF-IDF Vectorizer for text feature extraction
from sklearn.model_selection import train_test_split  # Splitting the data into training and testing sets
from sklearn.naive_bayes import MultinomialNB  # Multinomial Naive Bayes classifier
from sklearn.metrics import classification_report  # Reporting classification metrics
from nltk.corpus import reuters  # NLTK Reuters corpus for text data
from nltk.corpus import stopwords  # NLTK stopwords for filtering common words
from nltk.tokenize import word_tokenize  # NLTK word tokenizer for text tokenization
from nltk.stem import PorterStemmer  # NLTK Porter Stemmer for word stemming

# %%
# Download NLTK resources (if not already downloaded)
import nltk
nltk.download("reuters")  # Download the Reuters corpus from NLTK
nltk.download("stopwords")  # Download NLTK stopwords
nltk.download("punkt")  # Download NLTK Punkt tokenizer for word tokenization

# Load Reuters-21578 dataset
documents = reuters.fileids()  # Get the file IDs of documents in the Reuters corpus
categories = reuters.categories()  # Get the list of categories in the Reuters corpus

# Define a function to preprocess and tokenize the documents
def preprocess_and_tokenize(document):
    stop_words = set(stopwords.words("english"))  # Get English stopwords from NLTK
    stemmer = PorterStemmer()  # Create a Porter Stemmer instance from NLTK
    words = word_tokenize(document)  # Tokenize the document using NLTK word tokenizer
    words = [stemmer.stem(word.lower()) for word in words if word.isalnum()]  # Stem and convert to lowercase
    words = [word for word in words if word not in stop_words]  # Remove stopwords
    return " ".join(words)  # Join the processed words into a string

# Preprocess and tokenize the documents
data = []
target = []
for doc_id in documents:
    category = reuters.categories(doc_id)[0]  # Get the category of the document
    document = reuters.raw(doc_id)  # Get the raw text of the document
    processed_doc = preprocess_and_tokenize(document)  # Preprocess and tokenize the document
    data.append(processed_doc)
    target.append(category)

# Convert data and target into a DataFrame
df = pd.DataFrame({'data': data, 'target': target})

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['data'], df['target'], test_size=0.2, random_state=42)

# Vectorize the text data using TF-IDF
vectorizer = TfidfVectorizer()  # Create a TF-IDF vectorizer instance
X_train_tfidf = vectorizer.fit_transform(X_train)  # Fit and transform the training data
X_test_tfidf = vectorizer.transform(X_test)  # Transform the test data using the fitted vectorizer

# Train a Multinomial Naive Bayes classifier
classifier = MultinomialNB()  # Create a Multinomial Naive Bayes classifier instance
classifier.fit(X_train_tfidf, y_train)  # Train the classifier using the TF-IDF transformed training data

# Predict categories on the test set
y_pred = classifier.predict(X_test_tfidf)

# Evaluate the classifier
report = classification_report(y_test, y_pred)  # Generate a classification report
print(report)  # Print the classification report to the console
# Out:
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                  precision    recall  f1-score   support
#
#             acq       0.54      0.96      0.69       469
#            alum       0.00      0.00      0.00         7
#          barley       0.00      0.00      0.00         6
#             bop       0.00      0.00      0.00        20
#         carcass       0.00      0.00      0.00        15
#      castor-oil       0.00      0.00      0.00         2
#           cocoa       0.00      0.00      0.00        17
#          coffee       0.00      0.00      0.00        25
#          copper       0.00      0.00      0.00         9
#            corn       1.00      0.21      0.34        48
#          cotton       0.00      0.00      0.00         8
#             cpi       0.00      0.00      0.00        19
#             cpu       0.00      0.00      0.00         1
#           crude       0.85      0.67      0.75        96
#             dlr       1.00      0.18      0.31        33
#            earn       0.72      0.98      0.83       780
#            fuel       0.00      0.00      0.00         1
#             gas       0.00      0.00      0.00         2
#             gnp       0.00      0.00      0.00        25
#            gold       0.00      0.00      0.00        31
#           grain       0.80      0.29      0.43        68
#            heat       0.00      0.00      0.00         5
#             hog       0.00      0.00      0.00         5
#         housing       0.00      0.00      0.00         2
#          income       0.00      0.00      0.00         3
#        interest       0.79      0.61      0.69       105
#             ipi       0.00      0.00      0.00         8
#      iron-steel       0.00      0.00      0.00         3
#             jet       0.00      0.00      0.00         2
#            jobs       0.00      0.00      0.00         9
#            lead       0.00      0.00      0.00         3
#             lei       0.00      0.00      0.00         1
#       livestock       0.00      0.00      0.00         4
#          lumber       0.00      0.00      0.00         2
#       meal-feed       0.00      0.00      0.00         4
#        money-fx       0.44      0.29      0.35        62
#    money-supply       0.00      0.00      0.00        32
#         nat-gas       0.00      0.00      0.00        10
#          nickel       0.00      0.00      0.00         1
#           nzdlr       0.00      0.00      0.00         1
#         oilseed       0.00      0.00      0.00         6
#          orange       0.00      0.00      0.00         8
#        palm-oil       0.00      0.00      0.00         7
#        pet-chem       0.00      0.00      0.00         5
#        platinum       0.00      0.00      0.00         2
#            rand       0.00      0.00      0.00         1
#        reserves       0.00      0.00      0.00        12
#          retail       0.00      0.00      0.00         4
#          rubber       0.00      0.00      0.00        10
#            ship       0.00      0.00      0.00        35
#         soybean       0.00      0.00      0.00         1
# strategic-metal       0.00      0.00      0.00         4
#           sugar       1.00      0.07      0.14        27
#         sun-oil       0.00      0.00      0.00         1
#             tin       0.00      0.00      0.00         7
#           trade       0.89      0.40      0.55        63
#         veg-oil       0.00      0.00      0.00         9
#             wpi       0.00      0.00      0.00         7
#             yen       0.00      0.00      0.00         3
#            zinc       0.00      0.00      0.00         2
#
#        accuracy                           0.66      2158
#       macro avg       0.13      0.08      0.08      2158
#    weighted avg       0.57      0.66      0.57      2158
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Import necessary library
import numpy as np  # NumPy for numerical operations

# Define the proportions for splitting the data
train_ratio = 0.7  # Set the proportion for the training set
test_ratio = 0.15  # Set the proportion for the test set

# Shuffle the data
df_shuffled = df.sample(frac=1, random_state=42)  # Shuffle the DataFrame randomly with a fixed seed

# Split the data into three categories: training set, test set, and unused set
train_size = int(train_ratio * len(df_shuffled))  # Calculate the size of the training set
test_size = int(test_ratio * len(df_shuffled))  # Calculate the size of the test set
unused_size = len(df_shuffled) - train_size - test_size  # Calculate the size of the unused set

# Assign IDs and group names
df_shuffled['id'] = range(len(df_shuffled))  # Assign unique IDs to each row
df_shuffled['group'] = np.where(df_shuffled.index < train_size, 'training_set', np.where(df_shuffled.index < train_size + test_size, 'test_set', 'unused_set'))  # Assign group names based on index

# Separate the data into the three categories
training_set = df_shuffled[df_shuffled['group'] == 'training_set']  # Extract rows belonging to the training set
test_set = df_shuffled[df_shuffled['group'] == 'test_set']  # Extract rows belonging to the test set
unused_set = df_shuffled[df_shuffled['group'] == 'unused_set']  # Extract rows belonging to the unused set

# Now, you have three separate DataFrames: training_set, test_set, and unused_set
# Each DataFrame contains data, target, id, and group columns
print("Training Set:")
print(training_set)

print("\nTest Set:")
print(test_set)

print("\nUnused Set:")
print(unused_set)
# Out:
# Training Set:
#                                                    data    target     id  \
# 4593  bayer world group 1986 profit billion mark bil...      earn      0
# 3614  comput microfilm corp lt comi year net shr 23 ...      earn      2
# 510   spain foreign reserv rise februari spain forei...  reserves      6
# 7331  gerber lt grb buy gerber system lt gsti share ...       acq      7
# 5458  santa anita realti lt sar quarterli dividend q...      earn      8
# ...                                                 ...       ...    ...
# 5734  dst system inc lt dst regular payout set qtli ...      earn  10783
# 5191  ocean inc lt obci year net shr eight ct vs sev...      earn  10784
# 5390  drexel offici ha stake epsilon data lt epsi se...       acq  10785
# 860   pennsylvania real estat invest trust lt pei op...      earn  10786
# 7270  circon corp lt ccon 4th qtr shr loss two ct vs...      earn  10787
#
#              group
# 4593  training_set
# 3614  training_set
# 510   training_set
# 7331  training_set
# 5458  training_set
# ...            ...
# 5734  training_set
# 5191  training_set
# 5390  training_set
# 860   training_set
# 7270  training_set
#
# [7551 rows x 4 columns]
#
# Test Set:
#                                                    data    target     id  \
# 8353  marcor lt maar expect fiscal year profit marco...      earn      1
# 8048  transamerica incom lt tai monthli dividend shr...      earn      4
# 8440  bank england said invit borrow 10 pct later to...  interest     16
# 8036  armtek lt arm unit leverag buyout complet cond...       acq     25
# 8811  fleet lt flt aim speed merger norstar fleet fi...       acq     28
# ...                                                 ...       ...    ...
# 7734  bank japan satisfi yen current rang bank japan...       gnp  10752
# 9167  intermark lt imi seek major pier 1 lt pir stak...       acq  10759
# 7849  diversifi industri lt dei 1st qtr oper net per...      earn  10762
# 8666  novar electron corp lt novr 4th qtr jan three ...      earn  10765
# 8322  hospit staf servic inc lt hssi 1st qtr feb 28 ...      earn  10778
#
#          group
# 8353  test_set
# 8048  test_set
# 8440  test_set
# 8036  test_set
# 8811  test_set
# ...        ...
# 7734  test_set
# 9167  test_set
# 7849  test_set
# 8666  test_set
# 8322  test_set
#
# [1618 rows x 4 columns]
#
# Unused Set:
#                                                     data    target     id  \
# 10382  iran say ha better weapon silkworm iranian pri...      ship      3
# 10334  avatar hold inc lt avtr year net oper shr 32 c...      earn      5
# 9730   alli lt asu sell michigan unit alli supermarke...       acq      9
# 9281   twa lt twa court settlement usair lt u tran wo...       acq     17
# 9451   mcm corp lt mcmc set quarterli qtli div six ct...      earn     22
# ...                                                  ...       ...    ...
# 10555  recent oil demand pct year ago oil demand meas...     crude  10743
# 10627  burlington coat factori warehous corp lt bcf n...      earn  10745
# 9998   claremont tell sec seek 15 pct champion produc...       acq  10758
# 9274   india australia agre improv trade indian austr...    cotton  10764
# 10583  baker say stand pari currenc agreement treasur...  money-fx  10775
#
#             group
# 10382  unused_set
# 10334  unused_set
# 9730   unused_set
# 9281   unused_set
# 9451   unused_set
# ...           ...
# 10555  unused_set
# 10627  unused_set
# 9998   unused_set
# 9274   unused_set
# 10583  unused_set
#
# [1619 rows x 4 columns]

# %%
pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)

# %%
import gensim
from gensim import corpora
import nltk
nltk.download("reuters")

# Your data preprocessing code here
# Out:
# [nltk_data] Downloading package reuters to /root/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# True

# %%
# Tokenize your data (assuming 'data' is your preprocessed text data)
tokenized_data = [document.split() for document in df['data']]
# Split each preprocessed document into a list of tokens (words) and store them in 'tokenized_data'

# Create a dictionary and a corpus
dictionary = corpora.Dictionary(tokenized_data)
# Create a Gensim Dictionary, which maps each unique token to a unique integer ID
corpus = [dictionary.doc2bow(text) for text in tokenized_data]
# Create a Gensim Corpus, which represents each document as a bag-of-words using the token IDs from the dictionary

# %%
# Define a function to run LDA with different numbers of topics
def run_lda(num_topics):
    lda_model = gensim.models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=15)
    return lda_model

# Try different numbers of topics
num_topics_list = [5, 10, 15, 20]

for num_topics in num_topics_list:
    print(f"Number of Topics: {num_topics}")  # Print the number of topics being evaluated
    lda_model = run_lda(num_topics)  # Run LDA with the specified number of topics
    topics = lda_model.print_topics(num_words=10)  # Get the top 10 words for each topic
    for topic in topics:
        print(topic)  # Print the words associated with each topic
    print("\n")  # Print a newline for better readability
# Out:
# Number of Topics: 5
# (0, '0.030*"tonn" + 0.025*"said" + 0.019*"mln" + 0.017*"export" + 0.012*"year" + 0.010*"wheat" + 0.010*"sugar" + 0.008*"agricultur" + 0.008*"product" + 0.008*"grain"')
# (1, '0.104*"vs" + 0.077*"mln" + 0.062*"ct" + 0.048*"net" + 0.041*"loss" + 0.037*"shr" + 0.036*"dlr" + 0.024*"lt" + 0.020*"profit" + 0.019*"qtr"')
# (2, '0.035*"pct" + 0.026*"said" + 0.026*"billion" + 0.024*"mln" + 0.022*"bank" + 0.020*"dlr" + 0.018*"year" + 0.013*"1986" + 0.011*"rate" + 0.008*"wa"')
# (3, '0.033*"said" + 0.011*"would" + 0.011*"trade" + 0.010*"wa" + 0.009*"oil" + 0.008*"market" + 0.007*"price" + 0.007*"ha" + 0.006*"japan" + 0.005*"thi"')
# (4, '0.042*"said" + 0.027*"lt" + 0.022*"compani" + 0.022*"share" + 0.018*"dlr" + 0.012*"inc" + 0.011*"corp" + 0.010*"ha" + 0.010*"pct" + 0.010*"mln"')
#
#
# Number of Topics: 10
# (0, '0.045*"said" + 0.030*"share" + 0.026*"lt" + 0.021*"compani" + 0.016*"stock" + 0.016*"offer" + 0.015*"inc" + 0.013*"pct" + 0.013*"ha" + 0.012*"dlr"')
# (1, '0.066*"dlr" + 0.044*"billion" + 0.036*"mln" + 0.030*"said" + 0.023*"year" + 0.017*"1986" + 0.014*"quarter" + 0.013*"compani" + 0.012*"earn" + 0.011*"first"')
# (2, '0.044*"said" + 0.034*"oil" + 0.021*"lt" + 0.016*"compani" + 0.015*"product" + 0.013*"unit" + 0.011*"price" + 0.011*"mln" + 0.011*"ga" + 0.011*"corp"')
# (3, '0.021*"said" + 0.019*"price" + 0.019*"coffe" + 0.019*"dlr" + 0.016*"gulf" + 0.015*"oil" + 0.015*"ship" + 0.012*"crude" + 0.010*"say" + 0.010*"brazil"')
# (4, '0.032*"said" + 0.017*"trade" + 0.015*"would" + 0.009*"wa" + 0.008*"offici" + 0.008*"ha" + 0.007*"countri" + 0.007*"state" + 0.007*"market" + 0.006*"export"')
# (5, '0.041*"mln" + 0.034*"stg" + 0.031*"gold" + 0.025*"mine" + 0.019*"said" + 0.019*"bank" + 0.018*"market" + 0.015*"ton" + 0.014*"money" + 0.013*"ounc"')
# (6, '0.040*"pct" + 0.028*"tonn" + 0.026*"said" + 0.021*"mln" + 0.020*"year" + 0.018*"export" + 0.015*"januari" + 0.014*"februari" + 0.012*"price" + 0.011*"wa"')
# (7, '0.033*"said" + 0.024*"bank" + 0.019*"rate" + 0.016*"pct" + 0.013*"market" + 0.013*"dollar" + 0.011*"wa" + 0.009*"thi" + 0.008*"currenc" + 0.008*"exchang"')
# (8, '0.091*"mln" + 0.035*"profit" + 0.025*"billion" + 0.020*"lt" + 0.019*"stg" + 0.019*"1986" + 0.018*"pct" + 0.017*"group" + 0.016*"franc" + 0.015*"ltd"')
# (9, '0.128*"vs" + 0.076*"ct" + 0.075*"mln" + 0.055*"net" + 0.046*"loss" + 0.046*"shr" + 0.033*"dlr" + 0.026*"lt" + 0.023*"qtr" + 0.021*"rev"')
#
#
# Number of Topics: 15
# (0, '0.128*"vs" + 0.077*"ct" + 0.076*"mln" + 0.054*"net" + 0.046*"shr" + 0.044*"loss" + 0.032*"dlr" + 0.026*"lt" + 0.023*"qtr" + 0.021*"profit"')
# (1, '0.048*"said" + 0.037*"lt" + 0.022*"compani" + 0.016*"inc" + 0.016*"corp" + 0.014*"dlr" + 0.013*"unit" + 0.013*"ha" + 0.011*"sale" + 0.010*"mln"')
# (2, '0.028*"gulf" + 0.025*"said" + 0.023*"ship" + 0.020*"wa" + 0.020*"dealer" + 0.016*"futur" + 0.014*"iran" + 0.013*"trader" + 0.012*"trade" + 0.011*"buy"')
# (3, '0.049*"rate" + 0.045*"bank" + 0.043*"dollar" + 0.030*"said" + 0.028*"currenc" + 0.027*"yen" + 0.021*"japan" + 0.020*"exchang" + 0.015*"market" + 0.014*"pari"')
# (4, '0.031*"mln" + 0.030*"said" + 0.017*"crop" + 0.017*"grain" + 0.017*"china" + 0.015*"wheat" + 0.015*"agricultur" + 0.015*"corn" + 0.014*"usda" + 0.014*"program"')
# (5, '0.040*"said" + 0.013*"year" + 0.013*"thi" + 0.012*"pct" + 0.011*"would" + 0.011*"market" + 0.011*"wa" + 0.009*"analyst" + 0.008*"expect" + 0.007*"growth"')
# (6, '0.145*"mln" + 0.074*"stg" + 0.027*"bank" + 0.026*"market" + 0.017*"money" + 0.016*"plc" + 0.015*"pct" + 0.014*"said" + 0.013*"england" + 0.011*"billion"')
# (7, '0.045*"share" + 0.042*"said" + 0.023*"offer" + 0.023*"stock" + 0.019*"lt" + 0.017*"compani" + 0.017*"pct" + 0.016*"dlr" + 0.012*"common" + 0.011*"sharehold"')
# (8, '0.030*"said" + 0.029*"trade" + 0.018*"would" + 0.011*"offici" + 0.010*"import" + 0.010*"japan" + 0.009*"wa" + 0.009*"state" + 0.008*"countri" + 0.007*"govern"')
# (9, '0.127*"billion" + 0.065*"bank" + 0.053*"dlr" + 0.024*"loan" + 0.022*"reserv" + 0.022*"mln" + 0.017*"mark" + 0.016*"pct" + 0.014*"franc" + 0.013*"surplu"')
# (10, '0.107*"pct" + 0.038*"januari" + 0.037*"februari" + 0.024*"rose" + 0.023*"year" + 0.022*"said" + 0.022*"rise" + 0.021*"1986" + 0.019*"wa" + 0.015*"decemb"')
# (11, '0.029*"price" + 0.029*"said" + 0.020*"produc" + 0.018*"coffe" + 0.018*"export" + 0.016*"quota" + 0.015*"brazil" + 0.015*"stock" + 0.014*"cocoa" + 0.013*"buffer"')
# (12, '0.115*"tonn" + 0.037*"sugar" + 0.036*"export" + 0.019*"wheat" + 0.018*"import" + 0.015*"week" + 0.014*"mln" + 0.014*"said" + 0.013*"shipment" + 0.012*"nil"')
# (13, '0.077*"dlr" + 0.066*"mln" + 0.040*"year" + 0.037*"1986" + 0.027*"quarter" + 0.027*"said" + 0.025*"earn" + 0.023*"profit" + 0.022*"compani" + 0.019*"1987"')
# (14, '0.051*"oil" + 0.037*"said" + 0.018*"price" + 0.013*"product" + 0.012*"ga" + 0.012*"barrel" + 0.012*"crude" + 0.010*"mine" + 0.010*"dlr" + 0.009*"compani"')
#
#
# Number of Topics: 20
# (0, '0.026*"said" + 0.019*"wa" + 0.016*"would" + 0.016*"offer" + 0.015*"compani" + 0.009*"cyclop" + 0.009*"court" + 0.008*"propos" + 0.008*"say" + 0.008*"takeov"')
# (1, '0.033*"said" + 0.028*"trade" + 0.016*"would" + 0.011*"govern" + 0.011*"offici" + 0.011*"japan" + 0.011*"import" + 0.010*"countri" + 0.009*"state" + 0.008*"industri"')
# (2, '0.046*"said" + 0.023*"price" + 0.018*"market" + 0.013*"thi" + 0.013*"would" + 0.012*"analyst" + 0.011*"wa" + 0.008*"could" + 0.007*"ha" + 0.007*"expect"')
# (3, '0.036*"said" + 0.025*"gold" + 0.024*"mine" + 0.019*"gulf" + 0.017*"ship" + 0.016*"union" + 0.013*"ton" + 0.012*"south" + 0.012*"strike" + 0.012*"wa"')
# (4, '0.027*"coffe" + 0.025*"stock" + 0.022*"brazil" + 0.022*"export" + 0.021*"said" + 0.020*"produc" + 0.020*"cocoa" + 0.020*"buffer" + 0.018*"new" + 0.017*"price"')
# (5, '0.059*"said" + 0.047*"lt" + 0.029*"unit" + 0.028*"inc" + 0.026*"corp" + 0.020*"compani" + 0.017*"sale" + 0.016*"ha" + 0.015*"co" + 0.014*"acquir"')
# (6, '0.088*"bank" + 0.046*"rate" + 0.024*"said" + 0.023*"pct" + 0.013*"interest" + 0.012*"market" + 0.012*"money" + 0.011*"cut" + 0.010*"foreign" + 0.010*"central"')
# (7, '0.076*"pct" + 0.054*"billion" + 0.026*"year" + 0.024*"januari" + 0.022*"februari" + 0.021*"said" + 0.019*"rise" + 0.019*"1986" + 0.018*"rose" + 0.015*"wa"')
# (8, '0.065*"dlr" + 0.060*"mln" + 0.034*"said" + 0.027*"year" + 0.021*"1986" + 0.021*"compani" + 0.016*"profit" + 0.015*"earn" + 0.012*"quarter" + 0.012*"sale"')
# (9, '0.032*"hong" + 0.031*"kong" + 0.027*"firm" + 0.025*"cabl" + 0.021*"telephon" + 0.020*"telecommun" + 0.019*"commun" + 0.018*"hotel" + 0.017*"san" + 0.016*"british"')
# (10, '0.039*"dollar" + 0.036*"said" + 0.023*"yen" + 0.021*"currenc" + 0.018*"japan" + 0.016*"exchang" + 0.013*"wa" + 0.013*"dealer" + 0.012*"baker" + 0.012*"west"')
# (11, '0.067*"mln" + 0.038*"tonn" + 0.025*"year" + 0.025*"said" + 0.021*"china" + 0.020*"crop" + 0.020*"product" + 0.017*"estim" + 0.017*"last" + 0.016*"sugar"')
# (12, '0.050*"share" + 0.050*"said" + 0.030*"lt" + 0.027*"pct" + 0.023*"compani" + 0.022*"dlr" + 0.020*"stock" + 0.019*"offer" + 0.014*"inc" + 0.014*"ha"')
# (13, '0.026*"program" + 0.023*"agricultur" + 0.022*"farm" + 0.021*"corn" + 0.020*"said" + 0.018*"soybean" + 0.017*"usda" + 0.015*"price" + 0.013*"farmer" + 0.012*"acr"')
# (14, '0.164*"oil" + 0.042*"ga" + 0.041*"barrel" + 0.040*"crude" + 0.032*"mln" + 0.031*"price" + 0.027*"energi" + 0.025*"bpd" + 0.024*"petroleum" + 0.023*"dlr"')
# (15, '0.140*"vs" + 0.092*"mln" + 0.067*"ct" + 0.062*"net" + 0.052*"shr" + 0.051*"loss" + 0.038*"dlr" + 0.026*"qtr" + 0.024*"rev" + 0.024*"profit"')
# (16, '0.052*"ltd" + 0.039*"canadian" + 0.036*"canada" + 0.024*"lt" + 0.020*"usair" + 0.019*"said" + 0.018*"pacif" + 0.016*"pct" + 0.014*"australian" + 0.013*"australia"')
# (17, '0.077*"ct" + 0.055*"april" + 0.042*"record" + 0.041*"dividend" + 0.034*"lt" + 0.030*"div" + 0.028*"pay" + 0.027*"may" + 0.027*"march" + 0.025*"prior"')
# (18, '0.067*"tonn" + 0.037*"export" + 0.027*"said" + 0.026*"wheat" + 0.021*"sugar" + 0.014*"soviet" + 0.013*"ec" + 0.012*"corn" + 0.012*"depart" + 0.012*"sale"')
# (19, '0.064*"stg" + 0.063*"mln" + 0.030*"bank" + 0.027*"market" + 0.025*"fed" + 0.025*"dlr" + 0.023*"reserv" + 0.021*"said" + 0.019*"money" + 0.018*"billion"')

# %%
# Import necessary libraries
import gensim  # Gensim for topic modeling
from gensim import corpora  # Gensim's corpora module for creating a dictionary and a corpus
import nltk  # Natural Language Toolkit for text processing
import pandas as pd  # Pandas for data manipulation and analysis
import numpy as np  # NumPy for numerical operations

# Your data preprocessing code here (assumed to be present but not provided)

# Tokenize your data (assuming 'data' is your preprocessed text data)
tokenized_data = [document.split() for document in df['data']]
# Split each preprocessed document into a list of tokens (words) and store them in 'tokenized_data'

# Create a dictionary and a corpus
dictionary = corpora.Dictionary(tokenized_data)
# Create a Gensim Dictionary, which maps each unique token to a unique integer ID
corpus = [dictionary.doc2bow(text) for text in tokenized_data]
# Create a Gensim Corpus, which represents each document as a bag-of-words using the token IDs from the dictionary

# Define a function to run LDA with different numbers of topics
def run_lda(num_topics):
    lda_model = gensim.models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=15)
    # Run LDA with the specified number of topics, using the dictionary and corpus created earlier
    return lda_model

# Try different numbers of topics
num_topics_list = [5]

for num_topics in num_topics_list:
    print(f"Number of Topics: {num_topics}")  # Print the number of topics being evaluated
    lda_model = run_lda(num_topics)  # Run LDA with the specified number of topics

    # Assign topics to documents
    topics_for_documents = [lda_model[document] for document in corpus]
    # Get the topics and their probabilities for each document in the corpus

    # Categorize documents into sets (training, test, unused)
    training_set_topics = [topics_for_documents[i] for i in training_set['id']]
    # Extract topics for documents in the training set
    test_set_topics = [topics_for_documents[i] for i in test_set['id']]
    # Extract topics for documents in the test set
    unused_set_topics = [topics_for_documents[i] for i in unused_set['id']]
    # Extract topics for documents in the unused set

    # Print the categorization for the training set
    print("Training Set Topics:")
    for i, topic_probabilities in enumerate(training_set_topics):
        max_topic = max(topic_probabilities, key=lambda x: x[1])
        print(f"Document {i} - Topic {max_topic[0]} with Probability {max_topic[1]}")
        # Print the document ID, assigned topic, and the probability of that topic

    # Print the categorization for the test set
    print("Test Set Topics:")
    for i, topic_probabilities in enumerate(test_set_topics):
        max_topic = max(topic_probabilities, key=lambda x: x[1])
        print(f"Document {i} - Topic {max_topic[0]} with Probability {max_topic[1]}")
        # Print the document ID, assigned topic, and the probability of that topic

    # Print the categorization for the unused set
    print("Unused Set Topics:")
    for i, topic_probabilities in enumerate(unused_set_topics):
        max_topic = max(topic_probabilities, key=lambda x: x[1])
        print(f"Document {i} - Topic {max_topic[0]} with Probability {max_topic[1]}")
        # Print the document ID, assigned topic, and the probability of that topic

    print("\n")  # Print a newline for better readability
# Out:
# Streaming output truncated to the last 5000 lines.
# Document 5792 - Topic 2 with Probability 0.9830993413925171
# Document 5793 - Topic 0 with Probability 0.6044766306877136
# Document 5794 - Topic 0 with Probability 0.9625720977783203
# Document 5795 - Topic 0 with Probability 0.9837740063667297
# Document 5796 - Topic 0 with Probability 0.984001100063324
# Document 5797 - Topic 4 with Probability 0.9857198596000671
# Document 5798 - Topic 4 with Probability 0.9850953817367554
# Document 5799 - Topic 4 with Probability 0.5043938755989075
# Document 5800 - Topic 4 with Probability 0.9792929887771606
# Document 5801 - Topic 2 with Probability 0.997636079788208
# Document 5802 - Topic 3 with Probability 0.7145045399665833
# Document 5803 - Topic 4 with Probability 0.34684258699417114
# Document 5804 - Topic 1 with Probability 0.9708993434906006
# Document 5805 - Topic 1 with Probability 0.989136815071106
# Document 5806 - Topic 4 with Probability 0.5665979385375977
# Document 5807 - Topic 3 with Probability 0.5406326055526733
# Document 5808 - Topic 4 with Probability 0.9866058230400085
# Document 5809 - Topic 0 with Probability 0.9851934313774109
# Document 5810 - Topic 3 with Probability 0.5918033719062805
# Document 5811 - Topic 2 with Probability 0.7447171807289124
# Document 5812 - Topic 4 with Probability 0.9554488658905029
# Document 5813 - Topic 4 with Probability 0.888963520526886
# Document 5814 - Topic 0 with Probability 0.9353696703910828
# Document 5815 - Topic 2 with Probability 0.8992904424667358
# Document 5816 - Topic 4 with Probability 0.972223699092865
# Document 5817 - Topic 4 with Probability 0.974051833152771
# Document 5818 - Topic 4 with Probability 0.9395104050636292
# Document 5819 - Topic 1 with Probability 0.8942664861679077
# Document 5820 - Topic 4 with Probability 0.8536433577537537
# Document 5821 - Topic 4 with Probability 0.9616805911064148
# Document 5822 - Topic 3 with Probability 0.8627706170082092
# Document 5823 - Topic 3 with Probability 0.622504472732544
# Document 5824 - Topic 2 with Probability 0.6788651347160339
# Document 5825 - Topic 4 with Probability 0.9553042650222778
# Document 5826 - Topic 2 with Probability 0.41321679949760437
# Document 5827 - Topic 2 with Probability 0.8692036271095276
# Document 5828 - Topic 4 with Probability 0.9721753597259521
# Document 5829 - Topic 0 with Probability 0.8171755075454712
# Document 5830 - Topic 3 with Probability 0.5788995623588562
# Document 5831 - Topic 4 with Probability 0.954501211643219
# Document 5832 - Topic 4 with Probability 0.9384151697158813
# Document 5833 - Topic 0 with Probability 0.9739871621131897
# Document 5834 - Topic 1 with Probability 0.8094070553779602
# Document 5835 - Topic 2 with Probability 0.5820397138595581
# Document 5836 - Topic 4 with Probability 0.9481198191642761
# Document 5837 - Topic 0 with Probability 0.9810824990272522
# Document 5838 - Topic 2 with Probability 0.4854452610015869
# Document 5839 - Topic 3 with Probability 0.4357682168483734
# Document 5840 - Topic 0 with Probability 0.20000000298023224
# Document 5841 - Topic 4 with Probability 0.9609903693199158
# Document 5842 - Topic 2 with Probability 0.8969677686691284
# Document 5843 - Topic 1 with Probability 0.48702073097229004
# Document 5844 - Topic 4 with Probability 0.9794161319732666
# Document 5845 - Topic 0 with Probability 0.7313510179519653
# Document 5846 - Topic 4 with Probability 0.9490891098976135
# Document 5847 - Topic 0 with Probability 0.4819597005844116
# Document 5848 - Topic 0 with Probability 0.6180142760276794
# Document 5849 - Topic 3 with Probability 0.8285066485404968
# Document 5850 - Topic 0 with Probability 0.5287660360336304
# Document 5851 - Topic 1 with Probability 0.7671799659729004
# Document 5852 - Topic 0 with Probability 0.5926732420921326
# Document 5853 - Topic 0 with Probability 0.4471636414527893
# Document 5854 - Topic 4 with Probability 0.9678143262863159
# Document 5855 - Topic 4 with Probability 0.9770448803901672
# Document 5856 - Topic 4 with Probability 0.9053530097007751
# Document 5857 - Topic 4 with Probability 0.9891247153282166
# Document 5858 - Topic 4 with Probability 0.9648505449295044
# Document 5859 - Topic 1 with Probability 0.9807420372962952
# Document 5860 - Topic 4 with Probability 0.9807066917419434
# Document 5861 - Topic 4 with Probability 0.979414165019989
# Document 5862 - Topic 4 with Probability 0.9467817544937134
# Document 5863 - Topic 0 with Probability 0.9274674654006958
# Document 5864 - Topic 4 with Probability 0.9901703596115112
# Document 5865 - Topic 2 with Probability 0.6845024228096008
# Document 5866 - Topic 4 with Probability 0.8979933857917786
# Document 5867 - Topic 2 with Probability 0.6016791462898254
# Document 5868 - Topic 1 with Probability 0.495873361825943
# Document 5869 - Topic 1 with Probability 0.4499112069606781
# Document 5870 - Topic 4 with Probability 0.8646212220191956
# Document 5871 - Topic 4 with Probability 0.9763694405555725
# Document 5872 - Topic 4 with Probability 0.9841709136962891
# Document 5873 - Topic 4 with Probability 0.9739481806755066
# Document 5874 - Topic 0 with Probability 0.9236345887184143
# Document 5875 - Topic 4 with Probability 0.9028282165527344
# Document 5876 - Topic 4 with Probability 0.6940036416053772
# Document 5877 - Topic 4 with Probability 0.9320297837257385
# Document 5878 - Topic 0 with Probability 0.5608539581298828
# Document 5879 - Topic 4 with Probability 0.9591347575187683
# Document 5880 - Topic 4 with Probability 0.8987088203430176
# Document 5881 - Topic 1 with Probability 0.96092289686203
# Document 5882 - Topic 4 with Probability 0.8078869581222534
# Document 5883 - Topic 2 with Probability 0.6263298392295837
# Document 5884 - Topic 4 with Probability 0.9830643534660339
# Document 5885 - Topic 4 with Probability 0.895005464553833
# Document 5886 - Topic 1 with Probability 0.7885432839393616
# Document 5887 - Topic 4 with Probability 0.8193173408508301
# Document 5888 - Topic 4 with Probability 0.9551385641098022
# Document 5889 - Topic 4 with Probability 0.9121084809303284
# Document 5890 - Topic 4 with Probability 0.5962490439414978
# Document 5891 - Topic 4 with Probability 0.9855738878250122
# Document 5892 - Topic 0 with Probability 0.8926234245300293
# Document 5893 - Topic 1 with Probability 0.5480697751045227
# Document 5894 - Topic 4 with Probability 0.9854066967964172
# Document 5895 - Topic 4 with Probability 0.7781614065170288
# Document 5896 - Topic 2 with Probability 0.6943320631980896
# Document 5897 - Topic 3 with Probability 0.6929669380187988
# Document 5898 - Topic 4 with Probability 0.7707107067108154
# Document 5899 - Topic 4 with Probability 0.6361993551254272
# Document 5900 - Topic 2 with Probability 0.7435224056243896
# Document 5901 - Topic 2 with Probability 0.6861143112182617
# Document 5902 - Topic 1 with Probability 0.8791442513465881
# Document 5903 - Topic 4 with Probability 0.9846161007881165
# Document 5904 - Topic 2 with Probability 0.7499441504478455
# Document 5905 - Topic 2 with Probability 0.5548508167266846
# Document 5906 - Topic 4 with Probability 0.8143522143363953
# Document 5907 - Topic 2 with Probability 0.6284557580947876
# Document 5908 - Topic 2 with Probability 0.9893110990524292
# Document 5909 - Topic 2 with Probability 0.8325525522232056
# Document 5910 - Topic 1 with Probability 0.8845378756523132
# Document 5911 - Topic 4 with Probability 0.7594910264015198
# Document 5912 - Topic 2 with Probability 0.8048530220985413
# Document 5913 - Topic 4 with Probability 0.9249250292778015
# Document 5914 - Topic 2 with Probability 0.9445371627807617
# Document 5915 - Topic 3 with Probability 0.3757876455783844
# Document 5916 - Topic 0 with Probability 0.4996500611305237
# Document 5917 - Topic 2 with Probability 0.9913509488105774
# Document 5918 - Topic 3 with Probability 0.8995140194892883
# Document 5919 - Topic 2 with Probability 0.6843718886375427
# Document 5920 - Topic 1 with Probability 0.7850456833839417
# Document 5921 - Topic 2 with Probability 0.946365237236023
# Document 5922 - Topic 2 with Probability 0.9800872802734375
# Document 5923 - Topic 0 with Probability 0.4084577262401581
# Document 5924 - Topic 0 with Probability 0.7442145943641663
# Document 5925 - Topic 2 with Probability 0.6981109380722046
# Document 5926 - Topic 0 with Probability 0.8038185834884644
# Document 5927 - Topic 3 with Probability 0.4936542212963104
# Document 5928 - Topic 3 with Probability 0.46492743492126465
# Document 5929 - Topic 3 with Probability 0.9037008881568909
# Document 5930 - Topic 2 with Probability 0.6346004605293274
# Document 5931 - Topic 1 with Probability 0.4838159680366516
# Document 5932 - Topic 1 with Probability 0.4161173105239868
# Document 5933 - Topic 0 with Probability 0.9788795709609985
# Document 5934 - Topic 3 with Probability 0.9911898970603943
# Document 5935 - Topic 1 with Probability 0.8991934657096863
# Document 5936 - Topic 0 with Probability 0.8126760721206665
# Document 5937 - Topic 0 with Probability 0.46080559492111206
# Document 5938 - Topic 3 with Probability 0.9565132856369019
# Document 5939 - Topic 1 with Probability 0.6532257795333862
# Document 5940 - Topic 4 with Probability 0.9200008511543274
# Document 5941 - Topic 3 with Probability 0.6626449227333069
# Document 5942 - Topic 3 with Probability 0.8375378847122192
# Document 5943 - Topic 0 with Probability 0.9571367502212524
# Document 5944 - Topic 0 with Probability 0.7089393138885498
# Document 5945 - Topic 3 with Probability 0.7420337796211243
# Document 5946 - Topic 0 with Probability 0.41694003343582153
# Document 5947 - Topic 1 with Probability 0.46385470032691956
# Document 5948 - Topic 2 with Probability 0.8950495719909668
# Document 5949 - Topic 4 with Probability 0.8800624012947083
# Document 5950 - Topic 4 with Probability 0.7743992209434509
# Document 5951 - Topic 4 with Probability 0.9839400053024292
# Document 5952 - Topic 4 with Probability 0.5069965720176697
# Document 5953 - Topic 1 with Probability 0.6420217156410217
# Document 5954 - Topic 4 with Probability 0.9901713728904724
# Document 5955 - Topic 3 with Probability 0.5809770226478577
# Document 5956 - Topic 4 with Probability 0.7724204063415527
# Document 5957 - Topic 4 with Probability 0.9418590068817139
# Document 5958 - Topic 3 with Probability 0.7343648672103882
# Document 5959 - Topic 4 with Probability 0.4964230954647064
# Document 5960 - Topic 1 with Probability 0.37794676423072815
# Document 5961 - Topic 2 with Probability 0.9891300797462463
# Document 5962 - Topic 2 with Probability 0.56950443983078
# Document 5963 - Topic 4 with Probability 0.9876582622528076
# Document 5964 - Topic 0 with Probability 0.6455959677696228
# Document 5965 - Topic 1 with Probability 0.7838148474693298
# Document 5966 - Topic 4 with Probability 0.9808899164199829
# Document 5967 - Topic 4 with Probability 0.9485543370246887
# Document 5968 - Topic 0 with Probability 0.7298346757888794
# Document 5969 - Topic 0 with Probability 0.9632763266563416
# Document 5970 - Topic 4 with Probability 0.9834710359573364
# Document 5971 - Topic 3 with Probability 0.5904130339622498
# Document 5972 - Topic 0 with Probability 0.6046738624572754
# Document 5973 - Topic 4 with Probability 0.9861491918563843
# Document 5974 - Topic 4 with Probability 0.8360739946365356
# Document 5975 - Topic 4 with Probability 0.9612681865692139
# Document 5976 - Topic 4 with Probability 0.9647547602653503
# Document 5977 - Topic 1 with Probability 0.4967387914657593
# Document 5978 - Topic 4 with Probability 0.9240996837615967
# Document 5979 - Topic 1 with Probability 0.5909699201583862
# Document 5980 - Topic 4 with Probability 0.9863130450248718
# Document 5981 - Topic 4 with Probability 0.9830252528190613
# Document 5982 - Topic 4 with Probability 0.8758447170257568
# Document 5983 - Topic 2 with Probability 0.4994598925113678
# Document 5984 - Topic 0 with Probability 0.9448195099830627
# Document 5985 - Topic 4 with Probability 0.8868958353996277
# Document 5986 - Topic 0 with Probability 0.5496392250061035
# Document 5987 - Topic 4 with Probability 0.9689851403236389
# Document 5988 - Topic 1 with Probability 0.5835174322128296
# Document 5989 - Topic 0 with Probability 0.9324987530708313
# Document 5990 - Topic 4 with Probability 0.3462538719177246
# Document 5991 - Topic 4 with Probability 0.3822477459907532
# Document 5992 - Topic 2 with Probability 0.9872994422912598
# Document 5993 - Topic 1 with Probability 0.6036627292633057
# Document 5994 - Topic 2 with Probability 0.3709678649902344
# Document 5995 - Topic 4 with Probability 0.9808236956596375
# Document 5996 - Topic 4 with Probability 0.9861627817153931
# Document 5997 - Topic 4 with Probability 0.9821747541427612
# Document 5998 - Topic 0 with Probability 0.9815073609352112
# Document 5999 - Topic 0 with Probability 0.5415409207344055
# Document 6000 - Topic 4 with Probability 0.9094948172569275
# Document 6001 - Topic 4 with Probability 0.9616088271141052
# Document 6002 - Topic 4 with Probability 0.6583408117294312
# Document 6003 - Topic 2 with Probability 0.5671314001083374
# Document 6004 - Topic 4 with Probability 0.6147416234016418
# Document 6005 - Topic 2 with Probability 0.7195069789886475
# Document 6006 - Topic 4 with Probability 0.7088861465454102
# Document 6007 - Topic 1 with Probability 0.5352160930633545
# Document 6008 - Topic 4 with Probability 0.5137894153594971
# Document 6009 - Topic 4 with Probability 0.8755120635032654
# Document 6010 - Topic 4 with Probability 0.8212653994560242
# Document 6011 - Topic 2 with Probability 0.802482008934021
# Document 6012 - Topic 4 with Probability 0.9892139434814453
# Document 6013 - Topic 2 with Probability 0.953855574131012
# Document 6014 - Topic 1 with Probability 0.7013275027275085
# Document 6015 - Topic 4 with Probability 0.5217298269271851
# Document 6016 - Topic 2 with Probability 0.7003219127655029
# Document 6017 - Topic 4 with Probability 0.9841020107269287
# Document 6018 - Topic 2 with Probability 0.8695055842399597
# Document 6019 - Topic 3 with Probability 0.4517197608947754
# Document 6020 - Topic 2 with Probability 0.6925917863845825
# Document 6021 - Topic 4 with Probability 0.9064329862594604
# Document 6022 - Topic 4 with Probability 0.8447296619415283
# Document 6023 - Topic 0 with Probability 0.8237394690513611
# Document 6024 - Topic 1 with Probability 0.7733221650123596
# Document 6025 - Topic 1 with Probability 0.8005588054656982
# Document 6026 - Topic 4 with Probability 0.891782283782959
# Document 6027 - Topic 3 with Probability 0.7387785911560059
# Document 6028 - Topic 2 with Probability 0.9844169616699219
# Document 6029 - Topic 0 with Probability 0.6446746587753296
# Document 6030 - Topic 0 with Probability 0.5313735604286194
# Document 6031 - Topic 1 with Probability 0.7013161778450012
# Document 6032 - Topic 0 with Probability 0.4559799134731293
# Document 6033 - Topic 2 with Probability 0.4870755970478058
# Document 6034 - Topic 4 with Probability 0.9853007197380066
# Document 6035 - Topic 4 with Probability 0.9756442904472351
# Document 6036 - Topic 4 with Probability 0.9631295800209045
# Document 6037 - Topic 2 with Probability 0.825157105922699
# Document 6038 - Topic 4 with Probability 0.8129377961158752
# Document 6039 - Topic 0 with Probability 0.6519038677215576
# Document 6040 - Topic 2 with Probability 0.5898506045341492
# Document 6041 - Topic 3 with Probability 0.5911915898323059
# Document 6042 - Topic 0 with Probability 0.8844443559646606
# Document 6043 - Topic 3 with Probability 0.9883877038955688
# Document 6044 - Topic 3 with Probability 0.6794949769973755
# Document 6045 - Topic 4 with Probability 0.9808467626571655
# Document 6046 - Topic 4 with Probability 0.8378519415855408
# Document 6047 - Topic 4 with Probability 0.7921856045722961
# Document 6048 - Topic 0 with Probability 0.8486246466636658
# Document 6049 - Topic 2 with Probability 0.7851501703262329
# Document 6050 - Topic 4 with Probability 0.9821702837944031
# Document 6051 - Topic 4 with Probability 0.9768126606941223
# Document 6052 - Topic 4 with Probability 0.9841632843017578
# Document 6053 - Topic 4 with Probability 0.9647618532180786
# Document 6054 - Topic 4 with Probability 0.9593198895454407
# Document 6055 - Topic 4 with Probability 0.9081295132637024
# Document 6056 - Topic 4 with Probability 0.9632572531700134
# Document 6057 - Topic 0 with Probability 0.8430503010749817
# Document 6058 - Topic 0 with Probability 0.8130518198013306
# Document 6059 - Topic 4 with Probability 0.9782974720001221
# Document 6060 - Topic 0 with Probability 0.8500940203666687
# Document 6061 - Topic 4 with Probability 0.9632408022880554
# Document 6062 - Topic 3 with Probability 0.7485023140907288
# Document 6063 - Topic 0 with Probability 0.638580322265625
# Document 6064 - Topic 0 with Probability 0.20000000298023224
# Document 6065 - Topic 3 with Probability 0.8605895042419434
# Document 6066 - Topic 2 with Probability 0.9840954542160034
# Document 6067 - Topic 0 with Probability 0.5638622045516968
# Document 6068 - Topic 2 with Probability 0.43410685658454895
# Document 6069 - Topic 0 with Probability 0.6553108096122742
# Document 6070 - Topic 4 with Probability 0.9811239242553711
# Document 6071 - Topic 0 with Probability 0.9730132818222046
# Document 6072 - Topic 4 with Probability 0.9573737978935242
# Document 6073 - Topic 1 with Probability 0.6914102435112
# Document 6074 - Topic 1 with Probability 0.6700896620750427
# Document 6075 - Topic 4 with Probability 0.9841756820678711
# Document 6076 - Topic 4 with Probability 0.6522771716117859
# Document 6077 - Topic 3 with Probability 0.4299352169036865
# Document 6078 - Topic 4 with Probability 0.7144373655319214
# Document 6079 - Topic 0 with Probability 0.4131852686405182
# Document 6080 - Topic 4 with Probability 0.9746997952461243
# Document 6081 - Topic 2 with Probability 0.7134400606155396
# Document 6082 - Topic 2 with Probability 0.6090053915977478
# Document 6083 - Topic 1 with Probability 0.48747676610946655
# Document 6084 - Topic 0 with Probability 0.4788886606693268
# Document 6085 - Topic 2 with Probability 0.581326425075531
# Document 6086 - Topic 1 with Probability 0.6643275022506714
# Document 6087 - Topic 4 with Probability 0.9804201722145081
# Document 6088 - Topic 4 with Probability 0.9744002223014832
# Document 6089 - Topic 0 with Probability 0.9811651110649109
# Document 6090 - Topic 0 with Probability 0.41836225986480713
# Document 6091 - Topic 4 with Probability 0.98179030418396
# Document 6092 - Topic 4 with Probability 0.850386917591095
# Document 6093 - Topic 4 with Probability 0.9671267867088318
# Document 6094 - Topic 0 with Probability 0.464138925075531
# Document 6095 - Topic 4 with Probability 0.9730363488197327
# Document 6096 - Topic 1 with Probability 0.42420336604118347
# Document 6097 - Topic 4 with Probability 0.977070689201355
# Document 6098 - Topic 2 with Probability 0.4885227680206299
# Document 6099 - Topic 0 with Probability 0.9493456482887268
# Document 6100 - Topic 0 with Probability 0.8800947666168213
# Document 6101 - Topic 4 with Probability 0.6677563190460205
# Document 6102 - Topic 3 with Probability 0.6668294668197632
# Document 6103 - Topic 4 with Probability 0.9064438343048096
# Document 6104 - Topic 0 with Probability 0.5001410841941833
# Document 6105 - Topic 0 with Probability 0.6745224595069885
# Document 6106 - Topic 4 with Probability 0.9704992175102234
# Document 6107 - Topic 4 with Probability 0.964905858039856
# Document 6108 - Topic 1 with Probability 0.9877121448516846
# Document 6109 - Topic 3 with Probability 0.9462230801582336
# Document 6110 - Topic 0 with Probability 0.7822172045707703
# Document 6111 - Topic 4 with Probability 0.9793927669525146
# Document 6112 - Topic 0 with Probability 0.9837701916694641
# Document 6113 - Topic 1 with Probability 0.3580557107925415
# Document 6114 - Topic 4 with Probability 0.9756271839141846
# Document 6115 - Topic 3 with Probability 0.8152267336845398
# Document 6116 - Topic 2 with Probability 0.5269080400466919
# Document 6117 - Topic 0 with Probability 0.7445659041404724
# Document 6118 - Topic 3 with Probability 0.885855495929718
# Document 6119 - Topic 3 with Probability 0.7042542695999146
# Document 6120 - Topic 4 with Probability 0.8887526988983154
# Document 6121 - Topic 4 with Probability 0.9736602902412415
# Document 6122 - Topic 4 with Probability 0.8540406227111816
# Document 6123 - Topic 4 with Probability 0.9763482213020325
# Document 6124 - Topic 4 with Probability 0.955446720123291
# Document 6125 - Topic 1 with Probability 0.3965276777744293
# Document 6126 - Topic 2 with Probability 0.687145471572876
# Document 6127 - Topic 4 with Probability 0.9412142038345337
# Document 6128 - Topic 0 with Probability 0.7879174947738647
# Document 6129 - Topic 0 with Probability 0.7013803720474243
# Document 6130 - Topic 4 with Probability 0.9804260730743408
# Document 6131 - Topic 3 with Probability 0.5205345153808594
# Document 6132 - Topic 4 with Probability 0.8376550078392029
# Document 6133 - Topic 4 with Probability 0.9617305994033813
# Document 6134 - Topic 4 with Probability 0.4783351421356201
# Document 6135 - Topic 0 with Probability 0.6788094639778137
# Document 6136 - Topic 0 with Probability 0.547365128993988
# Document 6137 - Topic 4 with Probability 0.9553357362747192
# Document 6138 - Topic 2 with Probability 0.5696620941162109
# Document 6139 - Topic 3 with Probability 0.4415108859539032
# Document 6140 - Topic 1 with Probability 0.9569311141967773
# Document 6141 - Topic 1 with Probability 0.6747687458992004
# Document 6142 - Topic 0 with Probability 0.9864169955253601
# Document 6143 - Topic 4 with Probability 0.9630659222602844
# Document 6144 - Topic 2 with Probability 0.5333824157714844
# Document 6145 - Topic 0 with Probability 0.8062595129013062
# Document 6146 - Topic 2 with Probability 0.7822489738464355
# Document 6147 - Topic 4 with Probability 0.9853991866111755
# Document 6148 - Topic 1 with Probability 0.4393729567527771
# Document 6149 - Topic 0 with Probability 0.5879424810409546
# Document 6150 - Topic 0 with Probability 0.7162145972251892
# Document 6151 - Topic 1 with Probability 0.7148396968841553
# Document 6152 - Topic 1 with Probability 0.9431705474853516
# Document 6153 - Topic 1 with Probability 0.6827353835105896
# Document 6154 - Topic 2 with Probability 0.6565800905227661
# Document 6155 - Topic 0 with Probability 0.8403582572937012
# Document 6156 - Topic 4 with Probability 0.966305136680603
# Document 6157 - Topic 3 with Probability 0.8965815305709839
# Document 6158 - Topic 4 with Probability 0.9663296341896057
# Document 6159 - Topic 1 with Probability 0.8927324414253235
# Document 6160 - Topic 2 with Probability 0.7582883834838867
# Document 6161 - Topic 1 with Probability 0.4732681214809418
# Document 6162 - Topic 0 with Probability 0.4937605857849121
# Document 6163 - Topic 4 with Probability 0.9170657396316528
# Document 6164 - Topic 0 with Probability 0.6823176145553589
# Document 6165 - Topic 4 with Probability 0.9552798867225647
# Document 6166 - Topic 2 with Probability 0.5798826813697815
# Document 6167 - Topic 1 with Probability 0.6430526971817017
# Document 6168 - Topic 1 with Probability 0.7801048159599304
# Document 6169 - Topic 1 with Probability 0.9466348886489868
# Document 6170 - Topic 2 with Probability 0.4659155011177063
# Document 6171 - Topic 1 with Probability 0.6210240125656128
# Document 6172 - Topic 1 with Probability 0.8872206807136536
# Document 6173 - Topic 3 with Probability 0.48328474164009094
# Document 6174 - Topic 1 with Probability 0.976223349571228
# Document 6175 - Topic 1 with Probability 0.6236752271652222
# Document 6176 - Topic 0 with Probability 0.9036911725997925
# Document 6177 - Topic 2 with Probability 0.7319896817207336
# Document 6178 - Topic 3 with Probability 0.6828488707542419
# Document 6179 - Topic 0 with Probability 0.5519234538078308
# Document 6180 - Topic 1 with Probability 0.5708029270172119
# Document 6181 - Topic 0 with Probability 0.5404055714607239
# Document 6182 - Topic 1 with Probability 0.7100014090538025
# Document 6183 - Topic 1 with Probability 0.7474546432495117
# Document 6184 - Topic 1 with Probability 0.6316530108451843
# Document 6185 - Topic 4 with Probability 0.9631953239440918
# Document 6186 - Topic 1 with Probability 0.9828638434410095
# Document 6187 - Topic 1 with Probability 0.8391337990760803
# Document 6188 - Topic 4 with Probability 0.967792809009552
# Document 6189 - Topic 1 with Probability 0.4469504952430725
# Document 6190 - Topic 2 with Probability 0.8305385708808899
# Document 6191 - Topic 2 with Probability 0.7769351601600647
# Document 6192 - Topic 4 with Probability 0.9667433500289917
# Document 6193 - Topic 4 with Probability 0.9616485238075256
# Document 6194 - Topic 0 with Probability 0.38777297735214233
# Document 6195 - Topic 0 with Probability 0.20000000298023224
# Document 6196 - Topic 1 with Probability 0.6028657555580139
# Document 6197 - Topic 1 with Probability 0.6936407089233398
# Document 6198 - Topic 4 with Probability 0.7166191339492798
# Document 6199 - Topic 2 with Probability 0.6735256910324097
# Document 6200 - Topic 4 with Probability 0.966166615486145
# Document 6201 - Topic 1 with Probability 0.7509492039680481
# Document 6202 - Topic 2 with Probability 0.5774539113044739
# Document 6203 - Topic 1 with Probability 0.8282702565193176
# Document 6204 - Topic 2 with Probability 0.537573516368866
# Document 6205 - Topic 1 with Probability 0.9042456746101379
# Document 6206 - Topic 4 with Probability 0.9616462588310242
# Document 6207 - Topic 1 with Probability 0.6292101144790649
# Document 6208 - Topic 0 with Probability 0.9503396153450012
# Document 6209 - Topic 2 with Probability 0.9729742407798767
# Document 6210 - Topic 2 with Probability 0.6995890736579895
# Document 6211 - Topic 2 with Probability 0.8524072170257568
# Document 6212 - Topic 2 with Probability 0.5230172276496887
# Document 6213 - Topic 3 with Probability 0.5425482392311096
# Document 6214 - Topic 2 with Probability 0.9961090683937073
# Document 6215 - Topic 0 with Probability 0.9564145803451538
# Document 6216 - Topic 0 with Probability 0.9784982800483704
# Document 6217 - Topic 1 with Probability 0.5568576455116272
# Document 6218 - Topic 1 with Probability 0.45729926228523254
# Document 6219 - Topic 4 with Probability 0.9722847938537598
# Document 6220 - Topic 3 with Probability 0.9613815546035767
# Document 6221 - Topic 0 with Probability 0.7071567177772522
# Document 6222 - Topic 0 with Probability 0.6134588718414307
# Document 6223 - Topic 0 with Probability 0.7107626795768738
# Document 6224 - Topic 2 with Probability 0.7283542156219482
# Document 6225 - Topic 0 with Probability 0.518787145614624
# Document 6226 - Topic 0 with Probability 0.5263664722442627
# Document 6227 - Topic 0 with Probability 0.9187177419662476
# Document 6228 - Topic 3 with Probability 0.952021598815918
# Document 6229 - Topic 4 with Probability 0.8113628029823303
# Document 6230 - Topic 1 with Probability 0.94721919298172
# Document 6231 - Topic 2 with Probability 0.6421212553977966
# Document 6232 - Topic 4 with Probability 0.9304683208465576
# Document 6233 - Topic 0 with Probability 0.7019232511520386
# Document 6234 - Topic 4 with Probability 0.9825625419616699
# Document 6235 - Topic 1 with Probability 0.5855515599250793
# Document 6236 - Topic 4 with Probability 0.9180333018302917
# Document 6237 - Topic 4 with Probability 0.9632164835929871
# Document 6238 - Topic 4 with Probability 0.8662309646606445
# Document 6239 - Topic 1 with Probability 0.811220109462738
# Document 6240 - Topic 2 with Probability 0.6959477663040161
# Document 6241 - Topic 1 with Probability 0.6526292562484741
# Document 6242 - Topic 0 with Probability 0.7616944313049316
# Document 6243 - Topic 0 with Probability 0.9415061473846436
# Document 6244 - Topic 4 with Probability 0.9097112417221069
# Document 6245 - Topic 4 with Probability 0.9782386422157288
# Document 6246 - Topic 2 with Probability 0.5386896133422852
# Document 6247 - Topic 1 with Probability 0.7706959843635559
# Document 6248 - Topic 1 with Probability 0.974564790725708
# Document 6249 - Topic 1 with Probability 0.724318265914917
# Document 6250 - Topic 4 with Probability 0.8520355224609375
# Document 6251 - Topic 0 with Probability 0.5120105743408203
# Document 6252 - Topic 0 with Probability 0.9850658178329468
# Document 6253 - Topic 0 with Probability 0.9589338302612305
# Document 6254 - Topic 4 with Probability 0.9836227893829346
# Document 6255 - Topic 1 with Probability 0.9613338112831116
# Document 6256 - Topic 1 with Probability 0.5622578263282776
# Document 6257 - Topic 0 with Probability 0.7931920289993286
# Document 6258 - Topic 4 with Probability 0.8412774801254272
# Document 6259 - Topic 1 with Probability 0.9469157457351685
# Document 6260 - Topic 0 with Probability 0.9506347179412842
# Document 6261 - Topic 4 with Probability 0.9659951329231262
# Document 6262 - Topic 4 with Probability 0.9799047112464905
# Document 6263 - Topic 2 with Probability 0.8415083885192871
# Document 6264 - Topic 0 with Probability 0.9885480403900146
# Document 6265 - Topic 4 with Probability 0.9680026769638062
# Document 6266 - Topic 3 with Probability 0.4948081970214844
# Document 6267 - Topic 4 with Probability 0.5725278854370117
# Document 6268 - Topic 1 with Probability 0.7531484961509705
# Document 6269 - Topic 4 with Probability 0.8340270519256592
# Document 6270 - Topic 4 with Probability 0.9892376661300659
# Document 6271 - Topic 2 with Probability 0.5251661539077759
# Document 6272 - Topic 4 with Probability 0.953040599822998
# Document 6273 - Topic 0 with Probability 0.8587207198143005
# Document 6274 - Topic 2 with Probability 0.9823281764984131
# Document 6275 - Topic 1 with Probability 0.6151278018951416
# Document 6276 - Topic 3 with Probability 0.7389143109321594
# Document 6277 - Topic 4 with Probability 0.7234508991241455
# Document 6278 - Topic 3 with Probability 0.37993767857551575
# Document 6279 - Topic 1 with Probability 0.883337140083313
# Document 6280 - Topic 4 with Probability 0.9824457764625549
# Document 6281 - Topic 0 with Probability 0.9809287786483765
# Document 6282 - Topic 4 with Probability 0.558605968952179
# Document 6283 - Topic 0 with Probability 0.6475728750228882
# Document 6284 - Topic 4 with Probability 0.971146285533905
# Document 6285 - Topic 4 with Probability 0.9832462668418884
# Document 6286 - Topic 4 with Probability 0.7208018898963928
# Document 6287 - Topic 0 with Probability 0.9139171242713928
# Document 6288 - Topic 1 with Probability 0.7414684295654297
# Document 6289 - Topic 0 with Probability 0.6543582081794739
# Document 6290 - Topic 4 with Probability 0.9045297503471375
# Document 6291 - Topic 0 with Probability 0.39860308170318604
# Document 6292 - Topic 0 with Probability 0.6474073529243469
# Document 6293 - Topic 2 with Probability 0.6064275503158569
# Document 6294 - Topic 2 with Probability 0.5935938358306885
# Document 6295 - Topic 0 with Probability 0.9790698885917664
# Document 6296 - Topic 4 with Probability 0.9588472843170166
# Document 6297 - Topic 0 with Probability 0.9611868262290955
# Document 6298 - Topic 3 with Probability 0.4727100729942322
# Document 6299 - Topic 0 with Probability 0.6742100715637207
# Document 6300 - Topic 3 with Probability 0.6687444448471069
# Document 6301 - Topic 4 with Probability 0.959736168384552
# Document 6302 - Topic 3 with Probability 0.9876170754432678
# Document 6303 - Topic 4 with Probability 0.9524466395378113
# Document 6304 - Topic 4 with Probability 0.517522931098938
# Document 6305 - Topic 0 with Probability 0.8031313419342041
# Document 6306 - Topic 4 with Probability 0.8899276852607727
# Document 6307 - Topic 3 with Probability 0.4909696877002716
# Document 6308 - Topic 4 with Probability 0.8820323944091797
# Document 6309 - Topic 4 with Probability 0.9596635699272156
# Document 6310 - Topic 4 with Probability 0.9589609503746033
# Document 6311 - Topic 4 with Probability 0.9624349474906921
# Document 6312 - Topic 4 with Probability 0.9622336030006409
# Document 6313 - Topic 4 with Probability 0.86465984582901
# Document 6314 - Topic 4 with Probability 0.9710474014282227
# Document 6315 - Topic 1 with Probability 0.8736788034439087
# Document 6316 - Topic 4 with Probability 0.9645947813987732
# Document 6317 - Topic 0 with Probability 0.7342936396598816
# Document 6318 - Topic 4 with Probability 0.9755550622940063
# Document 6319 - Topic 2 with Probability 0.6584241390228271
# Document 6320 - Topic 0 with Probability 0.898803174495697
# Document 6321 - Topic 2 with Probability 0.6858032941818237
# Document 6322 - Topic 4 with Probability 0.9888214468955994
# Document 6323 - Topic 2 with Probability 0.9954826235771179
# Document 6324 - Topic 0 with Probability 0.5106301307678223
# Document 6325 - Topic 2 with Probability 0.9928351640701294
# Document 6326 - Topic 2 with Probability 0.9879516363143921
# Document 6327 - Topic 0 with Probability 0.6040469408035278
# Document 6328 - Topic 0 with Probability 0.7214613556861877
# Document 6329 - Topic 3 with Probability 0.6358026266098022
# Document 6330 - Topic 0 with Probability 0.741477370262146
# Document 6331 - Topic 4 with Probability 0.9616618752479553
# Document 6332 - Topic 2 with Probability 0.6237597465515137
# Document 6333 - Topic 0 with Probability 0.36532777547836304
# Document 6334 - Topic 2 with Probability 0.6707567572593689
# Document 6335 - Topic 4 with Probability 0.8054773211479187
# Document 6336 - Topic 0 with Probability 0.7963935732841492
# Document 6337 - Topic 4 with Probability 0.9726237058639526
# Document 6338 - Topic 4 with Probability 0.9797379374504089
# Document 6339 - Topic 1 with Probability 0.4343952536582947
# Document 6340 - Topic 2 with Probability 0.5473289489746094
# Document 6341 - Topic 0 with Probability 0.7218946814537048
# Document 6342 - Topic 4 with Probability 0.9702256917953491
# Document 6343 - Topic 0 with Probability 0.8528184294700623
# Document 6344 - Topic 0 with Probability 0.9269899129867554
# Document 6345 - Topic 0 with Probability 0.6801022291183472
# Document 6346 - Topic 4 with Probability 0.9630835652351379
# Document 6347 - Topic 0 with Probability 0.5289290547370911
# Document 6348 - Topic 0 with Probability 0.7301631569862366
# Document 6349 - Topic 3 with Probability 0.7095879316329956
# Document 6350 - Topic 0 with Probability 0.9312708377838135
# Document 6351 - Topic 2 with Probability 0.6244621276855469
# Document 6352 - Topic 1 with Probability 0.4816855788230896
# Document 6353 - Topic 0 with Probability 0.6128758192062378
# Document 6354 - Topic 3 with Probability 0.8276875615119934
# Document 6355 - Topic 0 with Probability 0.9348211884498596
# Document 6356 - Topic 1 with Probability 0.5179942846298218
# Document 6357 - Topic 0 with Probability 0.8431965112686157
# Document 6358 - Topic 2 with Probability 0.990683913230896
# Document 6359 - Topic 0 with Probability 0.5166195034980774
# Document 6360 - Topic 0 with Probability 0.6581390500068665
# Document 6361 - Topic 4 with Probability 0.9630306959152222
# Document 6362 - Topic 0 with Probability 0.9859070777893066
# Document 6363 - Topic 4 with Probability 0.9818605780601501
# Document 6364 - Topic 1 with Probability 0.9465828537940979
# Document 6365 - Topic 4 with Probability 0.8842613697052002
# Document 6366 - Topic 1 with Probability 0.938113272190094
# Document 6367 - Topic 2 with Probability 0.9353832006454468
# Document 6368 - Topic 1 with Probability 0.939364492893219
# Document 6369 - Topic 3 with Probability 0.8596263527870178
# Document 6370 - Topic 4 with Probability 0.9831458926200867
# Document 6371 - Topic 4 with Probability 0.7275756001472473
# Document 6372 - Topic 4 with Probability 0.9823856949806213
# Document 6373 - Topic 2 with Probability 0.9676994681358337
# Document 6374 - Topic 0 with Probability 0.9422666430473328
# Document 6375 - Topic 3 with Probability 0.7190887928009033
# Document 6376 - Topic 4 with Probability 0.8867390751838684
# Document 6377 - Topic 4 with Probability 0.964917778968811
# Document 6378 - Topic 2 with Probability 0.49712684750556946
# Document 6379 - Topic 2 with Probability 0.6246415972709656
# Document 6380 - Topic 3 with Probability 0.5459755659103394
# Document 6381 - Topic 3 with Probability 0.2820066213607788
# Document 6382 - Topic 2 with Probability 0.7395914793014526
# Document 6383 - Topic 1 with Probability 0.29871857166290283
# Document 6384 - Topic 2 with Probability 0.6022859215736389
# Document 6385 - Topic 0 with Probability 0.6378976702690125
# Document 6386 - Topic 0 with Probability 0.8985465168952942
# Document 6387 - Topic 1 with Probability 0.5993552803993225
# Document 6388 - Topic 4 with Probability 0.9872742295265198
# Document 6389 - Topic 4 with Probability 0.9808845520019531
# Document 6390 - Topic 4 with Probability 0.35310083627700806
# Document 6391 - Topic 2 with Probability 0.343982458114624
# Document 6392 - Topic 4 with Probability 0.9203416705131531
# Document 6393 - Topic 1 with Probability 0.6799930334091187
# Document 6394 - Topic 0 with Probability 0.7860888242721558
# Document 6395 - Topic 3 with Probability 0.590137779712677
# Document 6396 - Topic 4 with Probability 0.9474363327026367
# Document 6397 - Topic 4 with Probability 0.9723206162452698
# Document 6398 - Topic 2 with Probability 0.6998687386512756
# Document 6399 - Topic 4 with Probability 0.8300647139549255
# Document 6400 - Topic 4 with Probability 0.9899451732635498
# Document 6401 - Topic 4 with Probability 0.7581292986869812
# Document 6402 - Topic 4 with Probability 0.8644466400146484
# Document 6403 - Topic 0 with Probability 0.5804846286773682
# Document 6404 - Topic 2 with Probability 0.6366702318191528
# Document 6405 - Topic 4 with Probability 0.8742784857749939
# Document 6406 - Topic 4 with Probability 0.8634170889854431
# Document 6407 - Topic 3 with Probability 0.6513837575912476
# Document 6408 - Topic 4 with Probability 0.9043897986412048
# Document 6409 - Topic 0 with Probability 0.578008770942688
# Document 6410 - Topic 0 with Probability 0.56290602684021
# Document 6411 - Topic 0 with Probability 0.6278504133224487
# Document 6412 - Topic 0 with Probability 0.9854555726051331
# Document 6413 - Topic 4 with Probability 0.889413595199585
# Document 6414 - Topic 4 with Probability 0.6926556825637817
# Document 6415 - Topic 0 with Probability 0.9227061867713928
# Document 6416 - Topic 4 with Probability 0.8877692222595215
# Document 6417 - Topic 0 with Probability 0.5851926803588867
# Document 6418 - Topic 4 with Probability 0.9860906600952148
# Document 6419 - Topic 2 with Probability 0.724851667881012
# Document 6420 - Topic 1 with Probability 0.604759156703949
# Document 6421 - Topic 0 with Probability 0.9790184497833252
# Document 6422 - Topic 4 with Probability 0.9776550531387329
# Document 6423 - Topic 4 with Probability 0.859955906867981
# Document 6424 - Topic 2 with Probability 0.561606228351593
# Document 6425 - Topic 2 with Probability 0.6776950359344482
# Document 6426 - Topic 2 with Probability 0.952743411064148
# Document 6427 - Topic 4 with Probability 0.9858709573745728
# Document 6428 - Topic 4 with Probability 0.8092151880264282
# Document 6429 - Topic 4 with Probability 0.9146499633789062
# Document 6430 - Topic 4 with Probability 0.9628286957740784
# Document 6431 - Topic 2 with Probability 0.7171357274055481
# Document 6432 - Topic 1 with Probability 0.9936836957931519
# Document 6433 - Topic 2 with Probability 0.8645777106285095
# Document 6434 - Topic 2 with Probability 0.7289966344833374
# Document 6435 - Topic 2 with Probability 0.9547436237335205
# Document 6436 - Topic 4 with Probability 0.8121997117996216
# Document 6437 - Topic 4 with Probability 0.8205799460411072
# Document 6438 - Topic 0 with Probability 0.6117648482322693
# Document 6439 - Topic 1 with Probability 0.6146069765090942
# Document 6440 - Topic 3 with Probability 0.8556553721427917
# Document 6441 - Topic 2 with Probability 0.508683443069458
# Document 6442 - Topic 2 with Probability 0.8273458480834961
# Document 6443 - Topic 2 with Probability 0.46727514266967773
# Document 6444 - Topic 2 with Probability 0.9854709506034851
# Document 6445 - Topic 2 with Probability 0.6499262452125549
# Document 6446 - Topic 1 with Probability 0.8750171661376953
# Document 6447 - Topic 1 with Probability 0.8003742694854736
# Document 6448 - Topic 4 with Probability 0.927966296672821
# Document 6449 - Topic 1 with Probability 0.5115587711334229
# Document 6450 - Topic 1 with Probability 0.7914126515388489
# Document 6451 - Topic 1 with Probability 0.9661975502967834
# Document 6452 - Topic 2 with Probability 0.9904386401176453
# Document 6453 - Topic 1 with Probability 0.9615297913551331
# Document 6454 - Topic 1 with Probability 0.9769715070724487
# Document 6455 - Topic 2 with Probability 0.5294555425643921
# Document 6456 - Topic 3 with Probability 0.7959986329078674
# Document 6457 - Topic 2 with Probability 0.44218534231185913
# Document 6458 - Topic 2 with Probability 0.8534517884254456
# Document 6459 - Topic 0 with Probability 0.20000000298023224
# Document 6460 - Topic 0 with Probability 0.8667500615119934
# Document 6461 - Topic 2 with Probability 0.5509853363037109
# Document 6462 - Topic 1 with Probability 0.9327026605606079
# Document 6463 - Topic 2 with Probability 0.6174969673156738
# Document 6464 - Topic 2 with Probability 0.9904410243034363
# Document 6465 - Topic 0 with Probability 0.8472456336021423
# Document 6466 - Topic 4 with Probability 0.9797742962837219
# Document 6467 - Topic 4 with Probability 0.8554129004478455
# Document 6468 - Topic 1 with Probability 0.977044403553009
# Document 6469 - Topic 2 with Probability 0.9054714441299438
# Document 6470 - Topic 2 with Probability 0.9932121634483337
# Document 6471 - Topic 0 with Probability 0.7463265657424927
# Document 6472 - Topic 2 with Probability 0.990966260433197
# Document 6473 - Topic 3 with Probability 0.6374296545982361
# Document 6474 - Topic 0 with Probability 0.572019100189209
# Document 6475 - Topic 2 with Probability 0.9340338706970215
# Document 6476 - Topic 2 with Probability 0.9020902514457703
# Document 6477 - Topic 4 with Probability 0.9819887280464172
# Document 6478 - Topic 0 with Probability 0.6734161376953125
# Document 6479 - Topic 0 with Probability 0.79864501953125
# Document 6480 - Topic 3 with Probability 0.7688738703727722
# Document 6481 - Topic 2 with Probability 0.945240318775177
# Document 6482 - Topic 0 with Probability 0.7197916507720947
# Document 6483 - Topic 1 with Probability 0.49371811747550964
# Document 6484 - Topic 0 with Probability 0.9611114263534546
# Document 6485 - Topic 2 with Probability 0.9937027096748352
# Document 6486 - Topic 0 with Probability 0.6728745698928833
# Document 6487 - Topic 3 with Probability 0.6496286988258362
# Document 6488 - Topic 2 with Probability 0.8083836436271667
# Document 6489 - Topic 0 with Probability 0.8904293179512024
# Document 6490 - Topic 0 with Probability 0.8175636529922485
# Document 6491 - Topic 0 with Probability 0.5817672610282898
# Document 6492 - Topic 4 with Probability 0.6066457629203796
# Document 6493 - Topic 4 with Probability 0.9799490571022034
# Document 6494 - Topic 0 with Probability 0.9744630455970764
# Document 6495 - Topic 0 with Probability 0.8957947492599487
# Document 6496 - Topic 3 with Probability 0.9233086109161377
# Document 6497 - Topic 4 with Probability 0.9590951204299927
# Document 6498 - Topic 4 with Probability 0.9649395942687988
# Document 6499 - Topic 4 with Probability 0.767864465713501
# Document 6500 - Topic 0 with Probability 0.7200527191162109
# Document 6501 - Topic 0 with Probability 0.648441731929779
# Document 6502 - Topic 3 with Probability 0.8426743149757385
# Document 6503 - Topic 1 with Probability 0.9903658628463745
# Document 6504 - Topic 4 with Probability 0.7264676690101624
# Document 6505 - Topic 3 with Probability 0.4454023838043213
# Document 6506 - Topic 0 with Probability 0.5531586408615112
# Document 6507 - Topic 4 with Probability 0.9634466171264648
# Document 6508 - Topic 2 with Probability 0.9449374675750732
# Document 6509 - Topic 0 with Probability 0.8830245137214661
# Document 6510 - Topic 2 with Probability 0.9767335057258606
# Document 6511 - Topic 0 with Probability 0.5214114189147949
# Document 6512 - Topic 4 with Probability 0.8516886830329895
# Document 6513 - Topic 4 with Probability 0.9710720777511597
# Document 6514 - Topic 4 with Probability 0.9763917326927185
# Document 6515 - Topic 0 with Probability 0.9021802544593811
# Document 6516 - Topic 4 with Probability 0.9527714252471924
# Document 6517 - Topic 4 with Probability 0.961539089679718
# Document 6518 - Topic 2 with Probability 0.5254213213920593
# Document 6519 - Topic 4 with Probability 0.9794184565544128
# Document 6520 - Topic 1 with Probability 0.42834267020225525
# Document 6521 - Topic 4 with Probability 0.48270151019096375
# Document 6522 - Topic 4 with Probability 0.9858432412147522
# Document 6523 - Topic 2 with Probability 0.3866649866104126
# Document 6524 - Topic 0 with Probability 0.20000000298023224
# Document 6525 - Topic 4 with Probability 0.9647725224494934
# Document 6526 - Topic 0 with Probability 0.55784010887146
# Document 6527 - Topic 3 with Probability 0.4904424250125885
# Document 6528 - Topic 4 with Probability 0.9218943119049072
# Document 6529 - Topic 4 with Probability 0.8778701424598694
# Document 6530 - Topic 4 with Probability 0.642909586429596
# Document 6531 - Topic 4 with Probability 0.9591000080108643
# Document 6532 - Topic 4 with Probability 0.9631602168083191
# Document 6533 - Topic 4 with Probability 0.9041494131088257
# Document 6534 - Topic 2 with Probability 0.3726743757724762
# Document 6535 - Topic 2 with Probability 0.8670873641967773
# Document 6536 - Topic 2 with Probability 0.4526619017124176
# Document 6537 - Topic 4 with Probability 0.6801624894142151
# Document 6538 - Topic 2 with Probability 0.6196597814559937
# Document 6539 - Topic 4 with Probability 0.9643886089324951
# Document 6540 - Topic 2 with Probability 0.9773980975151062
# Document 6541 - Topic 3 with Probability 0.9646433591842651
# Document 6542 - Topic 4 with Probability 0.9780184626579285
# Document 6543 - Topic 1 with Probability 0.5531272888183594
# Document 6544 - Topic 4 with Probability 0.9646129012107849
# Document 6545 - Topic 4 with Probability 0.854884922504425
# Document 6546 - Topic 4 with Probability 0.9629635810852051
# Document 6547 - Topic 0 with Probability 0.6112253665924072
# Document 6548 - Topic 3 with Probability 0.7096356153488159
# Document 6549 - Topic 1 with Probability 0.4501288831233978
# Document 6550 - Topic 0 with Probability 0.9520260691642761
# Document 6551 - Topic 0 with Probability 0.8439151048660278
# Document 6552 - Topic 2 with Probability 0.37675750255584717
# Document 6553 - Topic 2 with Probability 0.5755643248558044
# Document 6554 - Topic 2 with Probability 0.9632089138031006
# Document 6555 - Topic 4 with Probability 0.6781176328659058
# Document 6556 - Topic 4 with Probability 0.9740041494369507
# Document 6557 - Topic 0 with Probability 0.9919388294219971
# Document 6558 - Topic 0 with Probability 0.7759089469909668
# Document 6559 - Topic 3 with Probability 0.9754130840301514
# Document 6560 - Topic 0 with Probability 0.9607102870941162
# Document 6561 - Topic 0 with Probability 0.9823946356773376
# Document 6562 - Topic 2 with Probability 0.5101097226142883
# Document 6563 - Topic 0 with Probability 0.9577738642692566
# Document 6564 - Topic 0 with Probability 0.9642707705497742
# Document 6565 - Topic 4 with Probability 0.9788286089897156
# Document 6566 - Topic 4 with Probability 0.9770827889442444
# Document 6567 - Topic 4 with Probability 0.9848576188087463
# Document 6568 - Topic 3 with Probability 0.5581435561180115
# Document 6569 - Topic 4 with Probability 0.9663847088813782
# Document 6570 - Topic 4 with Probability 0.9322829246520996
# Document 6571 - Topic 4 with Probability 0.9865463972091675
# Document 6572 - Topic 0 with Probability 0.5688595175743103
# Document 6573 - Topic 4 with Probability 0.4587814211845398
# Document 6574 - Topic 4 with Probability 0.966355562210083
# Document 6575 - Topic 1 with Probability 0.9881685376167297
# Document 6576 - Topic 4 with Probability 0.9617544412612915
# Document 6577 - Topic 4 with Probability 0.5129126906394958
# Document 6578 - Topic 0 with Probability 0.9872442483901978
# Document 6579 - Topic 4 with Probability 0.9627954959869385
# Document 6580 - Topic 2 with Probability 0.5060886740684509
# Document 6581 - Topic 4 with Probability 0.8473591804504395
# Document 6582 - Topic 3 with Probability 0.5486190319061279
# Document 6583 - Topic 2 with Probability 0.9571340680122375
# Document 6584 - Topic 4 with Probability 0.8557140827178955
# Document 6585 - Topic 0 with Probability 0.9787006974220276
# Document 6586 - Topic 4 with Probability 0.7686451077461243
# Document 6587 - Topic 0 with Probability 0.8413244485855103
# Document 6588 - Topic 0 with Probability 0.8940597176551819
# Document 6589 - Topic 0 with Probability 0.5975631475448608
# Document 6590 - Topic 0 with Probability 0.3451423943042755
# Document 6591 - Topic 2 with Probability 0.7208485007286072
# ...
# Document 1353 - Topic 0 with Probability 0.9049517512321472
# Document 1354 - Topic 1 with Probability 0.44820287823677063
# Document 1355 - Topic 4 with Probability 0.9145280718803406
# Document 1356 - Topic 2 with Probability 0.6434115767478943
# Document 1357 - Topic 1 with Probability 0.6696814298629761
# Document 1358 - Topic 1 with Probability 0.37139543890953064
# Document 1359 - Topic 0 with Probability 0.6915115118026733
# Document 1360 - Topic 4 with Probability 0.9748831987380981
# Document 1361 - Topic 1 with Probability 0.48075979948043823
# Document 1362 - Topic 2 with Probability 0.9779982566833496
# Document 1363 - Topic 1 with Probability 0.712668776512146
# Document 1364 - Topic 0 with Probability 0.9172351360321045
# Document 1365 - Topic 4 with Probability 0.8107471466064453
# Document 1366 - Topic 0 with Probability 0.9103643894195557
# Document 1367 - Topic 4 with Probability 0.9378688335418701
# Document 1368 - Topic 4 with Probability 0.9738820195198059
# Document 1369 - Topic 4 with Probability 0.9763861298561096
# Document 1370 - Topic 4 with Probability 0.8368086814880371
# Document 1371 - Topic 4 with Probability 0.9615753293037415
# Document 1372 - Topic 2 with Probability 0.9852343797683716
# Document 1373 - Topic 0 with Probability 0.5086988210678101
# Document 1374 - Topic 2 with Probability 0.6731379628181458
# Document 1375 - Topic 4 with Probability 0.9807392358779907
# Document 1376 - Topic 4 with Probability 0.9788750410079956
# Document 1377 - Topic 0 with Probability 0.7297680377960205
# Document 1378 - Topic 3 with Probability 0.6332188248634338
# Document 1379 - Topic 2 with Probability 0.3103259205818176
# Document 1380 - Topic 0 with Probability 0.5286538004875183
# Document 1381 - Topic 1 with Probability 0.9381697773933411
# Document 1382 - Topic 0 with Probability 0.9801664352416992
# Document 1383 - Topic 0 with Probability 0.28537988662719727
# Document 1384 - Topic 4 with Probability 0.980193555355072
# Document 1385 - Topic 0 with Probability 0.89336097240448
# Document 1386 - Topic 4 with Probability 0.7217726111412048
# Document 1387 - Topic 2 with Probability 0.8930721282958984
# Document 1388 - Topic 2 with Probability 0.7016337513923645
# Document 1389 - Topic 2 with Probability 0.5294569134712219
# Document 1390 - Topic 2 with Probability 0.9020915627479553
# Document 1391 - Topic 1 with Probability 0.470342218875885
# Document 1392 - Topic 1 with Probability 0.5703384280204773
# Document 1393 - Topic 2 with Probability 0.750723123550415
# Document 1394 - Topic 1 with Probability 0.7615265250205994
# Document 1395 - Topic 1 with Probability 0.9884857535362244
# Document 1396 - Topic 0 with Probability 0.5226425528526306
# Document 1397 - Topic 2 with Probability 0.5035243034362793
# Document 1398 - Topic 2 with Probability 0.6932874917984009
# Document 1399 - Topic 3 with Probability 0.7002977728843689
# Document 1400 - Topic 2 with Probability 0.7171427011489868
# Document 1401 - Topic 1 with Probability 0.42475685477256775
# Document 1402 - Topic 0 with Probability 0.977537214756012
# Document 1403 - Topic 0 with Probability 0.4905066192150116
# Document 1404 - Topic 2 with Probability 0.950150728225708
# Document 1405 - Topic 2 with Probability 0.4975930452346802
# Document 1406 - Topic 0 with Probability 0.5455046892166138
# Document 1407 - Topic 4 with Probability 0.9807448983192444
# Document 1408 - Topic 0 with Probability 0.8313827514648438
# Document 1409 - Topic 4 with Probability 0.8896995782852173
# Document 1410 - Topic 2 with Probability 0.7911736965179443
# Document 1411 - Topic 4 with Probability 0.9505980610847473
# Document 1412 - Topic 2 with Probability 0.9952622652053833
# Document 1413 - Topic 2 with Probability 0.6079674363136292
# Document 1414 - Topic 1 with Probability 0.4695156216621399
# Document 1415 - Topic 3 with Probability 0.8098001480102539
# Document 1416 - Topic 0 with Probability 0.9525213241577148
# Document 1417 - Topic 0 with Probability 0.8326416015625
# Document 1418 - Topic 1 with Probability 0.43226051330566406
# Document 1419 - Topic 4 with Probability 0.9617851376533508
# Document 1420 - Topic 2 with Probability 0.9008861780166626
# Document 1421 - Topic 4 with Probability 0.44999921321868896
# Document 1422 - Topic 4 with Probability 0.9712969660758972
# Document 1423 - Topic 1 with Probability 0.7021698951721191
# Document 1424 - Topic 1 with Probability 0.8510497808456421
# Document 1425 - Topic 4 with Probability 0.9632877111434937
# Document 1426 - Topic 2 with Probability 0.9939712285995483
# Document 1427 - Topic 0 with Probability 0.9372617602348328
# Document 1428 - Topic 4 with Probability 0.7455806732177734
# Document 1429 - Topic 0 with Probability 0.6684911251068115
# Document 1430 - Topic 4 with Probability 0.34451791644096375
# Document 1431 - Topic 0 with Probability 0.9549381136894226
# Document 1432 - Topic 4 with Probability 0.904856264591217
# Document 1433 - Topic 0 with Probability 0.9480750560760498
# Document 1434 - Topic 2 with Probability 0.2765504717826843
# Document 1435 - Topic 0 with Probability 0.8055832386016846
# Document 1436 - Topic 4 with Probability 0.49122098088264465
# Document 1437 - Topic 0 with Probability 0.38316449522972107
# Document 1438 - Topic 0 with Probability 0.8231859803199768
# Document 1439 - Topic 2 with Probability 0.6317833662033081
# Document 1440 - Topic 2 with Probability 0.6675688028335571
# Document 1441 - Topic 2 with Probability 0.9299455881118774
# Document 1442 - Topic 3 with Probability 0.8809328079223633
# Document 1443 - Topic 1 with Probability 0.4001351594924927
# Document 1444 - Topic 1 with Probability 0.5708805918693542
# Document 1445 - Topic 2 with Probability 0.80345219373703
# Document 1446 - Topic 3 with Probability 0.9687447547912598
# Document 1447 - Topic 4 with Probability 0.47625815868377686
# Document 1448 - Topic 2 with Probability 0.947690486907959
# Document 1449 - Topic 4 with Probability 0.9883119463920593
# Document 1450 - Topic 2 with Probability 0.97640460729599
# Document 1451 - Topic 2 with Probability 0.8977366089820862
# Document 1452 - Topic 1 with Probability 0.7117489576339722
# Document 1453 - Topic 3 with Probability 0.7397429347038269
# Document 1454 - Topic 2 with Probability 0.9890850782394409
# Document 1455 - Topic 1 with Probability 0.6317466497421265
# Document 1456 - Topic 1 with Probability 0.6923288702964783
# Document 1457 - Topic 4 with Probability 0.9384757876396179
# Document 1458 - Topic 2 with Probability 0.8577869534492493
# Document 1459 - Topic 0 with Probability 0.5290095806121826
# Document 1460 - Topic 0 with Probability 0.9843725562095642
# Document 1461 - Topic 0 with Probability 0.6656874418258667
# Document 1462 - Topic 4 with Probability 0.9136508703231812
# Document 1463 - Topic 4 with Probability 0.977052628993988
# Document 1464 - Topic 4 with Probability 0.9617310166358948
# Document 1465 - Topic 1 with Probability 0.38896530866622925
# Document 1466 - Topic 1 with Probability 0.9852761030197144
# Document 1467 - Topic 4 with Probability 0.9813972115516663
# Document 1468 - Topic 4 with Probability 0.9787075519561768
# Document 1469 - Topic 0 with Probability 0.9752288460731506
# Document 1470 - Topic 0 with Probability 0.721790075302124
# Document 1471 - Topic 4 with Probability 0.8667725920677185
# Document 1472 - Topic 4 with Probability 0.9872506260871887
# Document 1473 - Topic 2 with Probability 0.7229341268539429
# Document 1474 - Topic 3 with Probability 0.7824153304100037
# Document 1475 - Topic 4 with Probability 0.9848166704177856
# Document 1476 - Topic 2 with Probability 0.936396062374115
# Document 1477 - Topic 4 with Probability 0.9804162979125977
# Document 1478 - Topic 2 with Probability 0.7616309523582458
# Document 1479 - Topic 3 with Probability 0.6859447360038757
# Document 1480 - Topic 0 with Probability 0.5747410655021667
# Document 1481 - Topic 0 with Probability 0.9753358960151672
# Document 1482 - Topic 1 with Probability 0.7590931057929993
# Document 1483 - Topic 0 with Probability 0.5802298188209534
# Document 1484 - Topic 4 with Probability 0.9355083703994751
# Document 1485 - Topic 4 with Probability 0.9021671414375305
# Document 1486 - Topic 2 with Probability 0.9879361987113953
# Document 1487 - Topic 2 with Probability 0.9526210427284241
# Document 1488 - Topic 1 with Probability 0.4769412875175476
# Document 1489 - Topic 1 with Probability 0.7225890159606934
# Document 1490 - Topic 2 with Probability 0.9383347034454346
# Document 1491 - Topic 4 with Probability 0.9493860602378845
# Document 1492 - Topic 4 with Probability 0.894806444644928
# Document 1493 - Topic 2 with Probability 0.9807189106941223
# Document 1494 - Topic 2 with Probability 0.9689458012580872
# Document 1495 - Topic 2 with Probability 0.9930935502052307
# Document 1496 - Topic 1 with Probability 0.5955005288124084
# Document 1497 - Topic 1 with Probability 0.8093477487564087
# Document 1498 - Topic 2 with Probability 0.5538259744644165
# Document 1499 - Topic 2 with Probability 0.9774844646453857
# Document 1500 - Topic 3 with Probability 0.7660871148109436
# Document 1501 - Topic 3 with Probability 0.9861354827880859
# Document 1502 - Topic 2 with Probability 0.7619298696517944
# Document 1503 - Topic 4 with Probability 0.796768307685852
# Document 1504 - Topic 0 with Probability 0.9774714112281799
# Document 1505 - Topic 2 with Probability 0.9869180917739868
# Document 1506 - Topic 2 with Probability 0.4388256072998047
# Document 1507 - Topic 0 with Probability 0.5926757454872131
# Document 1508 - Topic 2 with Probability 0.8215317726135254
# Document 1509 - Topic 4 with Probability 0.9562578201293945
# Document 1510 - Topic 1 with Probability 0.49824538826942444
# Document 1511 - Topic 0 with Probability 0.6631647944450378
# Document 1512 - Topic 0 with Probability 0.9885068535804749
# Document 1513 - Topic 1 with Probability 0.5886347889900208
# Document 1514 - Topic 4 with Probability 0.9870468378067017
# Document 1515 - Topic 3 with Probability 0.9115726947784424
# Document 1516 - Topic 2 with Probability 0.760788083076477
# Document 1517 - Topic 4 with Probability 0.9583638906478882
# Document 1518 - Topic 4 with Probability 0.9616137742996216
# Document 1519 - Topic 4 with Probability 0.9799273610115051
# Document 1520 - Topic 4 with Probability 0.9749073386192322
# Document 1521 - Topic 4 with Probability 0.9631306529045105
# Document 1522 - Topic 0 with Probability 0.8742323517799377
# Document 1523 - Topic 4 with Probability 0.9847853183746338
# Document 1524 - Topic 4 with Probability 0.9824991226196289
# Document 1525 - Topic 4 with Probability 0.9057362675666809
# Document 1526 - Topic 4 with Probability 0.9949384927749634
# Document 1527 - Topic 2 with Probability 0.9699877500534058
# Document 1528 - Topic 1 with Probability 0.3627445101737976
# Document 1529 - Topic 1 with Probability 0.9874549508094788
# Document 1530 - Topic 4 with Probability 0.4653533399105072
# Document 1531 - Topic 0 with Probability 0.8810260891914368
# Document 1532 - Topic 2 with Probability 0.4503210484981537
# Document 1533 - Topic 2 with Probability 0.9577442407608032
# Document 1534 - Topic 4 with Probability 0.9633706212043762
# Document 1535 - Topic 2 with Probability 0.9914906024932861
# Document 1536 - Topic 0 with Probability 0.7800750732421875
# Document 1537 - Topic 2 with Probability 0.8325223326683044
# Document 1538 - Topic 3 with Probability 0.8105407357215881
# Document 1539 - Topic 0 with Probability 0.7427335381507874
# Document 1540 - Topic 4 with Probability 0.9798802137374878
# Document 1541 - Topic 1 with Probability 0.8416191339492798
# Document 1542 - Topic 4 with Probability 0.48349618911743164
# Document 1543 - Topic 4 with Probability 0.9741808772087097
# Document 1544 - Topic 2 with Probability 0.9616427421569824
# Document 1545 - Topic 0 with Probability 0.6953436136245728
# Document 1546 - Topic 4 with Probability 0.7568984031677246
# Document 1547 - Topic 2 with Probability 0.4050656855106354
# Document 1548 - Topic 2 with Probability 0.9934749603271484
# Document 1549 - Topic 3 with Probability 0.9916695952415466
# Document 1550 - Topic 3 with Probability 0.7749423980712891
# Document 1551 - Topic 1 with Probability 0.46522095799446106
# Document 1552 - Topic 2 with Probability 0.9934765100479126
# Document 1553 - Topic 3 with Probability 0.7057493329048157
# Document 1554 - Topic 0 with Probability 0.9831020832061768
# Document 1555 - Topic 4 with Probability 0.9832711219787598
# Document 1556 - Topic 0 with Probability 0.9686129093170166
# Document 1557 - Topic 4 with Probability 0.974058210849762
# Document 1558 - Topic 3 with Probability 0.9871188402175903
# Document 1559 - Topic 2 with Probability 0.9380422830581665
# Document 1560 - Topic 0 with Probability 0.9629986882209778
# Document 1561 - Topic 2 with Probability 0.6962903141975403
# Document 1562 - Topic 1 with Probability 0.5323490500450134
# Document 1563 - Topic 1 with Probability 0.9785621166229248
# Document 1564 - Topic 0 with Probability 0.5012555718421936
# Document 1565 - Topic 2 with Probability 0.8568786978721619
# Document 1566 - Topic 0 with Probability 0.9801536798477173
# Document 1567 - Topic 3 with Probability 0.45870575308799744
# Document 1568 - Topic 1 with Probability 0.7119835615158081
# Document 1569 - Topic 4 with Probability 0.9869577884674072
# Document 1570 - Topic 3 with Probability 0.5099683403968811
# Document 1571 - Topic 0 with Probability 0.5253660678863525
# Document 1572 - Topic 3 with Probability 0.6337970495223999
# Document 1573 - Topic 3 with Probability 0.7438564896583557
# Document 1574 - Topic 4 with Probability 0.963398277759552
# Document 1575 - Topic 0 with Probability 0.871185839176178
# Document 1576 - Topic 3 with Probability 0.5200562477111816
# Document 1577 - Topic 2 with Probability 0.9835399389266968
# Document 1578 - Topic 3 with Probability 0.5317250490188599
# Document 1579 - Topic 2 with Probability 0.7768703699111938
# Document 1580 - Topic 2 with Probability 0.651528000831604
# Document 1581 - Topic 4 with Probability 0.9674161672592163
# Document 1582 - Topic 4 with Probability 0.9634413719177246
# Document 1583 - Topic 2 with Probability 0.349651038646698
# Document 1584 - Topic 2 with Probability 0.5763342976570129
# Document 1585 - Topic 0 with Probability 0.7817986607551575
# Document 1586 - Topic 4 with Probability 0.9868327379226685
# Document 1587 - Topic 0 with Probability 0.8931519389152527
# Document 1588 - Topic 0 with Probability 0.7967382669448853
# Document 1589 - Topic 3 with Probability 0.6376001834869385
# Document 1590 - Topic 2 with Probability 0.9317020177841187
# Document 1591 - Topic 2 with Probability 0.8262782692909241
# Document 1592 - Topic 2 with Probability 0.9956450462341309
# Document 1593 - Topic 2 with Probability 0.9877792000770569
# Document 1594 - Topic 2 with Probability 0.8254841566085815
# Document 1595 - Topic 2 with Probability 0.6324673891067505
# Document 1596 - Topic 1 with Probability 0.9782232046127319
# Document 1597 - Topic 4 with Probability 0.9052869081497192
# Document 1598 - Topic 2 with Probability 0.9898369312286377
# Document 1599 - Topic 2 with Probability 0.9980896711349487
# Document 1600 - Topic 2 with Probability 0.5137860178947449
# Document 1601 - Topic 2 with Probability 0.47525012493133545
# Document 1602 - Topic 1 with Probability 0.9613545536994934
# Document 1603 - Topic 2 with Probability 0.8120998740196228
# Document 1604 - Topic 2 with Probability 0.9617974758148193
# Document 1605 - Topic 0 with Probability 0.3666263520717621
# Document 1606 - Topic 0 with Probability 0.8514681458473206
# Document 1607 - Topic 4 with Probability 0.9802888035774231
# Document 1608 - Topic 4 with Probability 0.9616796970367432
# Document 1609 - Topic 1 with Probability 0.8986186981201172
# Document 1610 - Topic 0 with Probability 0.9546031951904297
# Document 1611 - Topic 0 with Probability 0.9776561856269836
# Document 1612 - Topic 0 with Probability 0.9847930073738098
# Document 1613 - Topic 2 with Probability 0.9472430348396301
# Document 1614 - Topic 0 with Probability 0.951887845993042
# Document 1615 - Topic 4 with Probability 0.9735017418861389
# Document 1616 - Topic 0 with Probability 0.3885781764984131
# Document 1617 - Topic 4 with Probability 0.9181561470031738
# Document 1618 - Topic 2 with Probability 0.5193901062011719

# %% [markdown]
# optimality number of categories  using topic modelling with categories and true cateriogized

# %%
# Import necessary library
from gensim.models import CoherenceModel

# Calculate coherence scores for different numbers of topics
coherence_scores = []  # Initialize an empty list to store coherence scores
for num_topics in num_topics_list:
    lda_model = run_lda(num_topics)  # Run LDA with the specified number of topics
    coherence_model_lda = CoherenceModel(model=lda_model, texts=tokenized_data, dictionary=dictionary, coherence='c_v')
    # Create a CoherenceModel instance for the LDA model using 'c_v' coherence
    coherence_score = coherence_model_lda.get_coherence()  # Calculate the coherence score
    coherence_scores.append(coherence_score)  # Append the coherence score to the list
    print(f"Number of Topics: {num_topics}, Coherence Score: {coherence_score}")
    # Print the number of topics and its corresponding coherence score

# Find the optimal number of topics based on coherence score
optimal_num_topics = num_topics_list[np.argmax(coherence_scores)]  # Get the number of topics with the highest coherence score
print(f"Optimal Number of Topics: {optimal_num_topics}")
# Print the optimal number of topics based on the highest coherence score
# Out:
# Number of Topics: 5, Coherence Score: 0.5024227698091698
# Optimal Number of Topics: 5

# %%
# Import necessary library
from gensim.models import CoherenceModel  # Import the CoherenceModel class from Gensim

import numpy as np  # Import NumPy for numerical operations


# Your code for calculating coherence scores

# Define the top-level categories
top_level_categories = ["earn", "acq", "money-fx", "grain", "crude", "trade", "interest", "ship"]

# Print the optimal number of topics
print(f"Optimal Number of Topics: {optimal_num_topics}")

# Print the top-level categories
print("Top-Level Categories:")
for i, category in enumerate(top_level_categories):
    print(f"{i+1}. {category}")
# Out:
# Optimal Number of Topics: 5
# Top-Level Categories:
# 1. earn
# 2. acq
# 3. money-fx
# 4. grain
# 5. crude
# 6. trade
# 7. interest
# 8. ship

# %%
# Import necessary libraries
import gensim  # Gensim for topic modeling
from gensim import corpora  # Gensim's corpora module for creating a dictionary and a corpus
import pandas as pd  # Pandas for data manipulation and analysis
from collections import defaultdict  # Import defaultdict from the collections module

# Your data preprocessing code here (assumed to be present but not provided)

# Tokenize your data (assuming 'data' is your preprocessed text data)
tokenized_data = [document.split() for document in df['data']]
# Split each preprocessed document into a list of tokens (words) and store them in 'tokenized_data'

# Create a dictionary and a corpus
dictionary = corpora.Dictionary(tokenized_data)
# Create a Gensim Dictionary, which maps each unique token to a unique integer ID
corpus = [dictionary.doc2bow(text) for text in tokenized_data]
# Create a Gensim Corpus, which represents each document as a bag-of-words using the token IDs from the dictionary

# Define a function to run LDA with a specific number of topics
def run_lda(num_topics):
    lda_model = gensim.models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=15)
    # Run LDA with the specified number of topics, using the dictionary and corpus created earlier
    return lda_model

# Number of topics
num_topics = 5  # Specify the number of topics for LDA

# Run LDA with 5 topics
lda_model = run_lda(num_topics)  # Run LDA with the specified number of topics

# Initialize a list to store categories
categories_list = []  # Create an empty list to store categories

# Calculate the word count for each category across the entire corpus
for category in categories:  # Iterate through each category (replace 'categories' with your actual category data)
    category_docs = df[df['target'] == category]  # Filter documents belonging to the current category

    if len(category_docs) > 0:  # Check if there are documents in the category
        categories_list.append(category)  # Append the category to the list if it has documents

# Print the categories
print("Categories:")
for category in categories_list:
    print(f"{category}")  # Print each category in the list
# Out:
# Categories:
# acq
# alum
# barley
# bop
# carcass
# castor-oil
# cocoa
# coconut
# coconut-oil
# coffee
# copper
# copra-cake
# corn
# cotton
# cotton-oil
# cpi
# cpu
# crude
# dfl
# dlr
# dmk
# earn
# fuel
# gas
# gnp
# gold
# grain
# groundnut
# groundnut-oil
# heat
# hog
# housing
# income
# instal-debt
# interest
# ipi
# iron-steel
# jet
# jobs
# l-cattle
# lead
# lei
# livestock
# lumber
# meal-feed
# money-fx
# money-supply
# naphtha
# nat-gas
# nickel
# nzdlr
# oilseed
# orange
# palladium
# palm-oil
# pet-chem
# platinum
# potato
# propane
# rand
# rape-oil
# reserves
# retail
# rice
# rubber
# ship
# silver
# soy-oil
# soybean
# strategic-metal
# sugar
# sun-oil
# tea
# tin
# trade
# veg-oil
# wpi
# yen
# zinc
